# %%
### STDC1 for Image classification

#Keras-tensorflow implementation

# -*- coding: utf-8 -*-


from functools import reduce
import tensorflow as tf
from tensorflow import keras
import numpy as np
import tensorflow.keras.backend as K


#### Custom function for conv2d: conv_block
def conv_block(inputs, conv_type, kernel, kernel_size, strides, padding='same'):
  
      if(conv_type == 'ds'):
        x = tf.keras.layers.SeparableConv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)
      else:
        x = tf.keras.layers.Conv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)  

      x = tf.keras.layers.BatchNormalization()(x)
      x = tf.keras.activations.relu(x)

      return x

def STDC_module(inputs, filters, kernel, s):
    
    
    tchannel1 = filters
    tchannel2 = tchannel1 // 2
    tchannel3 = tchannel1 // 4
    tchannel4 = tchannel1 // 8

    if s==2:
        x1 = conv_block(inputs, 'conv', tchannel2, (1, 1), strides=(1, 1)) #
        x2 = conv_block(x1, 'conv', tchannel3, (3, 3), strides=(s, s))
        x3 = conv_block(x2, 'conv', tchannel4, (3, 3), strides=(1, 1))
        x4 = conv_block(x3, 'conv', tchannel4, (3, 3), strides=(1, 1))

        #Used MaxPooling instead of average pooling
        x1 = tf.keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x1)
    
    else:
        x1 = conv_block(inputs, 'conv', tchannel2, (1, 1), strides=(1, 1))
        x2 = conv_block(x1, 'conv', tchannel3, (3, 3), strides=(1, 1))
        x3 = conv_block(x2, 'conv', tchannel4, (3, 3), strides=(1, 1))
        x4 = conv_block(x3, 'conv', tchannel4, (3, 3), strides=(1, 1))

    
    
    concat = tf.keras.layers.Concatenate()([x1, x2, x3, x4])

    return concat


"""#### STDC_block to control the repetition of STDC modules"""

def STDC_block(inputs, filters, kernel, strides, n):
      x = STDC_module(inputs, filters, kernel, strides)

      for i in range(1, n):
        x = STDC_module(x, filters, kernel, 1)

      return x    

def model(num_classes=19, input_size=(1024, 2048, 3)):

      # Input Layer
      input_layer = tf.keras.layers.Input(shape=input_size, name = 'input_layer')

      ## Step 1: Learning to DownSample
      convx1 = conv_block(input_layer, 'conv', 32, (3, 3), strides = (2, 2))

      convx2 = conv_block(convx1, 'conv', 64, (3, 3), strides = (2, 2))

      #STDC blocks  
      D3 = STDC_block(convx2, 256, (3, 3), strides=2, n=2)

      D4 = STDC_block(D3, 512, (3, 3), strides=2, n=2)

      D5 = STDC_block(D4, 1024, (3, 3), strides=2, n=2)
        
      convx6 = conv_block(D5, 'conv', 1024, (1, 1), strides = (1, 1))
    
      x = tf.keras.layers.GlobalAveragePooling2D()(convx6)
      x = tf.keras.layers.Dense(1024, activation=None)(x)
      x = tf.keras.layers.Dense(1000, activation=None)(x)

      STDC1 = tf.keras.Model(inputs = input_layer , outputs = x, name = 'STDC1')

      return STDC1

# %%
STDC1 = model(num_classes=1000, input_size=(1024, 2048, 3))
STDC1.summary()
# Out:
# Model: "STDC1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 1024, 2048,  0           []
#                                  3)]
#
#  conv2d_210 (Conv2D)            (None, 512, 1024, 3  896         ['input_layer[0][0]']
#                                 2)
#
#  batch_normalization_210 (Batch  (None, 512, 1024, 3  128        ['conv2d_210[0][0]']
#  Normalization)                 2)
#
#  tf.nn.relu_210 (TFOpLambda)    (None, 512, 1024, 3  0           ['batch_normalization_210[0][0]']
#                                 2)
#
#  conv2d_211 (Conv2D)            (None, 256, 512, 64  18496       ['tf.nn.relu_210[0][0]']
#                                 )
#
#  batch_normalization_211 (Batch  (None, 256, 512, 64  256        ['conv2d_211[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_211 (TFOpLambda)    (None, 256, 512, 64  0           ['batch_normalization_211[0][0]']
#                                 )
#
#  conv2d_212 (Conv2D)            (None, 256, 512, 12  8320        ['tf.nn.relu_211[0][0]']
#                                 8)
#
#  batch_normalization_212 (Batch  (None, 256, 512, 12  512        ['conv2d_212[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_212 (TFOpLambda)    (None, 256, 512, 12  0           ['batch_normalization_212[0][0]']
#                                 8)
#
#  conv2d_213 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_212[0][0]']
#                                 )
#
#  batch_normalization_213 (Batch  (None, 128, 256, 64  256        ['conv2d_213[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_213 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_213[0][0]']
#                                 )
#
#  conv2d_214 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_213[0][0]']
#                                 )
#
#  batch_normalization_214 (Batch  (None, 128, 256, 32  128        ['conv2d_214[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_214 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_214[0][0]']
#                                 )
#
#  conv2d_215 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_214[0][0]']
#                                 )
#
#  batch_normalization_215 (Batch  (None, 128, 256, 32  128        ['conv2d_215[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_18 (MaxPooling2D  (None, 128, 256, 12  0          ['tf.nn.relu_212[0][0]']
#  )                              8)
#
#  tf.nn.relu_215 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_215[0][0]']
#                                 )
#
#  concatenate_48 (Concatenate)   (None, 128, 256, 25  0           ['max_pooling2d_18[0][0]',
#                                 6)                                'tf.nn.relu_213[0][0]',
#                                                                   'tf.nn.relu_214[0][0]',
#                                                                   'tf.nn.relu_215[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 128, 256, 12  32896       ['concatenate_48[0][0]']
#                                 8)
#
#  batch_normalization_216 (Batch  (None, 128, 256, 12  512        ['conv2d_216[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_216 (TFOpLambda)    (None, 128, 256, 12  0           ['batch_normalization_216[0][0]']
#                                 8)
#
#  conv2d_217 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_216[0][0]']
#                                 )
#
#  batch_normalization_217 (Batch  (None, 128, 256, 64  256        ['conv2d_217[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_217 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_217[0][0]']
#                                 )
#
#  conv2d_218 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_217[0][0]']
#                                 )
#
#  batch_normalization_218 (Batch  (None, 128, 256, 32  128        ['conv2d_218[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_218 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_218[0][0]']
#                                 )
#
#  conv2d_219 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_218[0][0]']
#                                 )
#
#  batch_normalization_219 (Batch  (None, 128, 256, 32  128        ['conv2d_219[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_219 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_219[0][0]']
#                                 )
#
#  concatenate_49 (Concatenate)   (None, 128, 256, 25  0           ['tf.nn.relu_216[0][0]',
#                                 6)                                'tf.nn.relu_217[0][0]',
#                                                                   'tf.nn.relu_218[0][0]',
#                                                                   'tf.nn.relu_219[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 128, 256, 25  65792       ['concatenate_49[0][0]']
#                                 6)
#
#  batch_normalization_220 (Batch  (None, 128, 256, 25  1024       ['conv2d_220[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_220 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_220[0][0]']
#                                 6)
#
#  conv2d_221 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_220[0][0]']
#                                 )
#
#  batch_normalization_221 (Batch  (None, 64, 128, 128  512        ['conv2d_221[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_221 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_221[0][0]']
#                                 )
#
#  conv2d_222 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_221[0][0]']
#
#  batch_normalization_222 (Batch  (None, 64, 128, 64)  256        ['conv2d_222[0][0]']
#  Normalization)
#
#  tf.nn.relu_222 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_222[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_222[0][0]']
#
#  batch_normalization_223 (Batch  (None, 64, 128, 64)  256        ['conv2d_223[0][0]']
#  Normalization)
#
#  max_pooling2d_19 (MaxPooling2D  (None, 64, 128, 256  0          ['tf.nn.relu_220[0][0]']
#  )                              )
#
#  tf.nn.relu_223 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_223[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 64, 128, 512  0           ['max_pooling2d_19[0][0]',
#                                 )                                 'tf.nn.relu_221[0][0]',
#                                                                   'tf.nn.relu_222[0][0]',
#                                                                   'tf.nn.relu_223[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_50[0][0]']
#                                 )
#
#  batch_normalization_224 (Batch  (None, 64, 128, 256  1024       ['conv2d_224[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_224 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_224[0][0]']
#                                 )
#
#  conv2d_225 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_224[0][0]']
#                                 )
#
#  batch_normalization_225 (Batch  (None, 64, 128, 128  512        ['conv2d_225[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_225 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_225[0][0]']
#                                 )
#
#  conv2d_226 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_225[0][0]']
#
#  batch_normalization_226 (Batch  (None, 64, 128, 64)  256        ['conv2d_226[0][0]']
#  Normalization)
#
#  tf.nn.relu_226 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_226[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_226[0][0]']
#
#  batch_normalization_227 (Batch  (None, 64, 128, 64)  256        ['conv2d_227[0][0]']
#  Normalization)
#
#  tf.nn.relu_227 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_227[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_224[0][0]',
#                                 )                                 'tf.nn.relu_225[0][0]',
#                                                                   'tf.nn.relu_226[0][0]',
#                                                                   'tf.nn.relu_227[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 64, 128, 512  262656      ['concatenate_51[0][0]']
#                                 )
#
#  batch_normalization_228 (Batch  (None, 64, 128, 512  2048       ['conv2d_228[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_228 (TFOpLambda)    (None, 64, 128, 512  0           ['batch_normalization_228[0][0]']
#                                 )
#
#  conv2d_229 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_228[0][0]']
#
#  batch_normalization_229 (Batch  (None, 32, 64, 256)  1024       ['conv2d_229[0][0]']
#  Normalization)
#
#  tf.nn.relu_229 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_229[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_229[0][0]']
#
#  batch_normalization_230 (Batch  (None, 32, 64, 128)  512        ['conv2d_230[0][0]']
#  Normalization)
#
#  tf.nn.relu_230 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_230[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_230[0][0]']
#
#  batch_normalization_231 (Batch  (None, 32, 64, 128)  512        ['conv2d_231[0][0]']
#  Normalization)
#
#  max_pooling2d_20 (MaxPooling2D  (None, 32, 64, 512)  0          ['tf.nn.relu_228[0][0]']
#  )
#
#  tf.nn.relu_231 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_231[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 32, 64, 1024  0           ['max_pooling2d_20[0][0]',
#                                 )                                 'tf.nn.relu_229[0][0]',
#                                                                   'tf.nn.relu_230[0][0]',
#                                                                   'tf.nn.relu_231[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 32, 64, 512)  524800      ['concatenate_52[0][0]']
#
#  batch_normalization_232 (Batch  (None, 32, 64, 512)  2048       ['conv2d_232[0][0]']
#  Normalization)
#
#  tf.nn.relu_232 (TFOpLambda)    (None, 32, 64, 512)  0           ['batch_normalization_232[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_232[0][0]']
#
#  batch_normalization_233 (Batch  (None, 32, 64, 256)  1024       ['conv2d_233[0][0]']
#  Normalization)
#
#  tf.nn.relu_233 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_233[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_233[0][0]']
#
#  batch_normalization_234 (Batch  (None, 32, 64, 128)  512        ['conv2d_234[0][0]']
#  Normalization)
#
#  tf.nn.relu_234 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_234[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_234[0][0]']
#
#  batch_normalization_235 (Batch  (None, 32, 64, 128)  512        ['conv2d_235[0][0]']
#  Normalization)
#
#  tf.nn.relu_235 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_235[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 32, 64, 1024  0           ['tf.nn.relu_232[0][0]',
#                                 )                                 'tf.nn.relu_233[0][0]',
#                                                                   'tf.nn.relu_234[0][0]',
#                                                                   'tf.nn.relu_235[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 32, 64, 1024  1049600     ['concatenate_53[0][0]']
#                                 )
#
#  batch_normalization_236 (Batch  (None, 32, 64, 1024  4096       ['conv2d_236[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_236 (TFOpLambda)    (None, 32, 64, 1024  0           ['batch_normalization_236[0][0]']
#                                 )
#
#  global_average_pooling2d_6 (Gl  (None, 1024)        0           ['tf.nn.relu_236[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 1024)         1049600     ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_13 (Dense)               (None, 1000)         1025000     ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 8,447,784
# Trainable params: 8,438,376
# Non-trainable params: 9,408
# __________________________________________________________________________________________________

# %%
#install keras-floops to get the flop counts of the model

# !pip install keras-flops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-flops
#   Downloading keras_flops-0.1.2-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: tensorflow<3.0,>=2.2 in /usr/local/lib/python3.7/dist-packages (from keras-flops) (2.9.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.6.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (21.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.12)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.21.6)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (4.1.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.17.3)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (57.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.49.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.9.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.27.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (14.0.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<3.0,>=2.2->keras-flops) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<3.0,>=2.2->keras-flops) (1.5.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.8.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (3.9.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (3.2.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow<3.0,>=2.2->keras-flops) (3.0.9)
# Installing collected packages: keras-flops
# Successfully installed keras-flops-0.1.2

# %%
#flops at 1024 x 2048x1536 resolution

#In litera

from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

from keras_flops import get_flops


# Calculae FLOPS for STDC1 classification model
flops = get_flops(STDC1, batch_size=1)
print(f"FLOPS: {flops / 10 ** 9:.03} G")
# Out:
# FLOPS: 67.4 G

# %%
### STDC2 for image classification

#Keras-tensorflow implementation

# -*- coding: utf-8 -*-

from functools import reduce
import tensorflow as tf
from tensorflow import keras
import numpy as np
import tensorflow.keras.backend as K


#### Custom function for conv2d: conv_block
def conv_block(inputs, conv_type, kernel, kernel_size, strides, padding='same'):
  
      if(conv_type == 'ds'):
        x = tf.keras.layers.SeparableConv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)
      else:
        x = tf.keras.layers.Conv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)  

      x = tf.keras.layers.BatchNormalization()(x)
      x = tf.keras.activations.relu(x)

      return x

def STDC_module(inputs, filters, kernel, s):
    
    
    tchannel1 = filters
    tchannel2 = tchannel1 // 2
    tchannel3 = tchannel1 // 4
    tchannel4 = tchannel1 // 8

    if s==2:
        x1 = conv_block(inputs, 'conv', tchannel2, (1, 1), strides=(1, 1)) #
        x2 = conv_block(x1, 'conv', tchannel3, (3, 3), strides=(s, s))
        x3 = conv_block(x2, 'conv', tchannel4, (3, 3), strides=(1, 1))
        x4 = conv_block(x3, 'conv', tchannel4, (3, 3), strides=(1, 1))

        #Used MaxPooling instead of average pooling
        x1 = tf.keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x1)
    
    else:
        x1 = conv_block(inputs, 'conv', tchannel2, (1, 1), strides=(1, 1))
        x2 = conv_block(x1, 'conv', tchannel3, (3, 3), strides=(1, 1))
        x3 = conv_block(x2, 'conv', tchannel4, (3, 3), strides=(1, 1))
        x4 = conv_block(x3, 'conv', tchannel4, (3, 3), strides=(1, 1))

    
    
    concat = tf.keras.layers.Concatenate()([x1, x2, x3, x4])

    return concat


"""#### STDC_block to control the repetition of STDC modules"""

def STDC_block(inputs, filters, kernel, strides, n):
      x = STDC_module(inputs, filters, kernel, strides)

      for i in range(1, n):
        x = STDC_module(x, filters, kernel, 1)

      return x    

def model(num_classes=19, input_size=(1024, 2048, 3)):

      # Input Layer
      input_layer = tf.keras.layers.Input(shape=input_size, name = 'input_layer')

      ## Step 1: Learning to DownSample
      convx1 = conv_block(input_layer, 'conv', 32, (3, 3), strides = (2, 2))

      convx2 = conv_block(convx1, 'conv', 64, (3, 3), strides = (2, 2))

      #STDC blocks  
      D3 = STDC_block(convx2, 256, (3, 3), strides=2, n=4)

      D4 = STDC_block(D3, 512, (3, 3), strides=2, n=5)

      D5 = STDC_block(D4, 1024, (3, 3), strides=2, n=3)
        
      convx6 = conv_block(D5, 'conv', 1024, (1, 1), strides = (1, 1))
    
      x = tf.keras.layers.GlobalAveragePooling2D()(convx6)
      x = tf.keras.layers.Dense(1024, activation=None)(x)
      x = tf.keras.layers.Dense(1000, activation=None)(x)

      STDC2 = tf.keras.Model(inputs = input_layer , outputs = x, name = 'STDC2')

      return STDC2

# %%
# As Cityscapes provides images at 1024 x 2048 resolution and model performance is evaluated based on 19 objetc classes
# So we determine model FLOPs at full input resolution

STDC2 = model(num_classes=1000, input_size=(1024, 2048, 3))
STDC2.summary()
# Out:
# Model: "STDC2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 1024, 2048,  0           []
#                                  3)]
#
#  conv2d_132 (Conv2D)            (None, 512, 1024, 3  896         ['input_layer[0][0]']
#                                 2)
#
#  batch_normalization_132 (Batch  (None, 512, 1024, 3  128        ['conv2d_132[0][0]']
#  Normalization)                 2)
#
#  tf.nn.relu_132 (TFOpLambda)    (None, 512, 1024, 3  0           ['batch_normalization_132[0][0]']
#                                 2)
#
#  conv2d_133 (Conv2D)            (None, 256, 512, 64  18496       ['tf.nn.relu_132[0][0]']
#                                 )
#
#  batch_normalization_133 (Batch  (None, 256, 512, 64  256        ['conv2d_133[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_133 (TFOpLambda)    (None, 256, 512, 64  0           ['batch_normalization_133[0][0]']
#                                 )
#
#  conv2d_134 (Conv2D)            (None, 256, 512, 12  8320        ['tf.nn.relu_133[0][0]']
#                                 8)
#
#  batch_normalization_134 (Batch  (None, 256, 512, 12  512        ['conv2d_134[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_134 (TFOpLambda)    (None, 256, 512, 12  0           ['batch_normalization_134[0][0]']
#                                 8)
#
#  conv2d_135 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_134[0][0]']
#                                 )
#
#  batch_normalization_135 (Batch  (None, 128, 256, 64  256        ['conv2d_135[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_135 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_135[0][0]']
#                                 )
#
#  conv2d_136 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_135[0][0]']
#                                 )
#
#  batch_normalization_136 (Batch  (None, 128, 256, 32  128        ['conv2d_136[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_136 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_136[0][0]']
#                                 )
#
#  conv2d_137 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_136[0][0]']
#                                 )
#
#  batch_normalization_137 (Batch  (None, 128, 256, 32  128        ['conv2d_137[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 128, 256, 12  0          ['tf.nn.relu_134[0][0]']
#  )                              8)
#
#  tf.nn.relu_137 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_137[0][0]']
#                                 )
#
#  concatenate_30 (Concatenate)   (None, 128, 256, 25  0           ['max_pooling2d_12[0][0]',
#                                 6)                                'tf.nn.relu_135[0][0]',
#                                                                   'tf.nn.relu_136[0][0]',
#                                                                   'tf.nn.relu_137[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 128, 256, 12  32896       ['concatenate_30[0][0]']
#                                 8)
#
#  batch_normalization_138 (Batch  (None, 128, 256, 12  512        ['conv2d_138[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_138 (TFOpLambda)    (None, 128, 256, 12  0           ['batch_normalization_138[0][0]']
#                                 8)
#
#  conv2d_139 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_138[0][0]']
#                                 )
#
#  batch_normalization_139 (Batch  (None, 128, 256, 64  256        ['conv2d_139[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_139 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_139[0][0]']
#                                 )
#
#  conv2d_140 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_139[0][0]']
#                                 )
#
#  batch_normalization_140 (Batch  (None, 128, 256, 32  128        ['conv2d_140[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_140 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_140[0][0]']
#                                 )
#
#  conv2d_141 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_140[0][0]']
#                                 )
#
#  batch_normalization_141 (Batch  (None, 128, 256, 32  128        ['conv2d_141[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_141 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_141[0][0]']
#                                 )
#
#  concatenate_31 (Concatenate)   (None, 128, 256, 25  0           ['tf.nn.relu_138[0][0]',
#                                 6)                                'tf.nn.relu_139[0][0]',
#                                                                   'tf.nn.relu_140[0][0]',
#                                                                   'tf.nn.relu_141[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 128, 256, 12  32896       ['concatenate_31[0][0]']
#                                 8)
#
#  batch_normalization_142 (Batch  (None, 128, 256, 12  512        ['conv2d_142[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_142 (TFOpLambda)    (None, 128, 256, 12  0           ['batch_normalization_142[0][0]']
#                                 8)
#
#  conv2d_143 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_142[0][0]']
#                                 )
#
#  batch_normalization_143 (Batch  (None, 128, 256, 64  256        ['conv2d_143[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_143 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_143[0][0]']
#                                 )
#
#  conv2d_144 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_143[0][0]']
#                                 )
#
#  batch_normalization_144 (Batch  (None, 128, 256, 32  128        ['conv2d_144[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_144 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_144[0][0]']
#                                 )
#
#  conv2d_145 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_144[0][0]']
#                                 )
#
#  batch_normalization_145 (Batch  (None, 128, 256, 32  128        ['conv2d_145[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_145 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_145[0][0]']
#                                 )
#
#  concatenate_32 (Concatenate)   (None, 128, 256, 25  0           ['tf.nn.relu_142[0][0]',
#                                 6)                                'tf.nn.relu_143[0][0]',
#                                                                   'tf.nn.relu_144[0][0]',
#                                                                   'tf.nn.relu_145[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 128, 256, 12  32896       ['concatenate_32[0][0]']
#                                 8)
#
#  batch_normalization_146 (Batch  (None, 128, 256, 12  512        ['conv2d_146[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_146 (TFOpLambda)    (None, 128, 256, 12  0           ['batch_normalization_146[0][0]']
#                                 8)
#
#  conv2d_147 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_146[0][0]']
#                                 )
#
#  batch_normalization_147 (Batch  (None, 128, 256, 64  256        ['conv2d_147[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_147 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_147[0][0]']
#                                 )
#
#  conv2d_148 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_147[0][0]']
#                                 )
#
#  batch_normalization_148 (Batch  (None, 128, 256, 32  128        ['conv2d_148[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_148 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_148[0][0]']
#                                 )
#
#  conv2d_149 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_148[0][0]']
#                                 )
#
#  batch_normalization_149 (Batch  (None, 128, 256, 32  128        ['conv2d_149[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_149 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_149[0][0]']
#                                 )
#
#  concatenate_33 (Concatenate)   (None, 128, 256, 25  0           ['tf.nn.relu_146[0][0]',
#                                 6)                                'tf.nn.relu_147[0][0]',
#                                                                   'tf.nn.relu_148[0][0]',
#                                                                   'tf.nn.relu_149[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 128, 256, 25  65792       ['concatenate_33[0][0]']
#                                 6)
#
#  batch_normalization_150 (Batch  (None, 128, 256, 25  1024       ['conv2d_150[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_150 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_150[0][0]']
#                                 6)
#
#  conv2d_151 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_150[0][0]']
#                                 )
#
#  batch_normalization_151 (Batch  (None, 64, 128, 128  512        ['conv2d_151[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_151 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_151[0][0]']
#                                 )
#
#  conv2d_152 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_151[0][0]']
#
#  batch_normalization_152 (Batch  (None, 64, 128, 64)  256        ['conv2d_152[0][0]']
#  Normalization)
#
#  tf.nn.relu_152 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_152[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_152[0][0]']
#
#  batch_normalization_153 (Batch  (None, 64, 128, 64)  256        ['conv2d_153[0][0]']
#  Normalization)
#
#  max_pooling2d_13 (MaxPooling2D  (None, 64, 128, 256  0          ['tf.nn.relu_150[0][0]']
#  )                              )
#
#  tf.nn.relu_153 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_153[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 64, 128, 512  0           ['max_pooling2d_13[0][0]',
#                                 )                                 'tf.nn.relu_151[0][0]',
#                                                                   'tf.nn.relu_152[0][0]',
#                                                                   'tf.nn.relu_153[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_34[0][0]']
#                                 )
#
#  batch_normalization_154 (Batch  (None, 64, 128, 256  1024       ['conv2d_154[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_154 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_154[0][0]']
#                                 )
#
#  conv2d_155 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_154[0][0]']
#                                 )
#
#  batch_normalization_155 (Batch  (None, 64, 128, 128  512        ['conv2d_155[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_155 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_155[0][0]']
#                                 )
#
#  conv2d_156 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_155[0][0]']
#
#  batch_normalization_156 (Batch  (None, 64, 128, 64)  256        ['conv2d_156[0][0]']
#  Normalization)
#
#  tf.nn.relu_156 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_156[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_156[0][0]']
#
#  batch_normalization_157 (Batch  (None, 64, 128, 64)  256        ['conv2d_157[0][0]']
#  Normalization)
#
#  tf.nn.relu_157 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_157[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_154[0][0]',
#                                 )                                 'tf.nn.relu_155[0][0]',
#                                                                   'tf.nn.relu_156[0][0]',
#                                                                   'tf.nn.relu_157[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_35[0][0]']
#                                 )
#
#  batch_normalization_158 (Batch  (None, 64, 128, 256  1024       ['conv2d_158[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_158 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_158[0][0]']
#                                 )
#
#  conv2d_159 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_158[0][0]']
#                                 )
#
#  batch_normalization_159 (Batch  (None, 64, 128, 128  512        ['conv2d_159[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_159 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_159[0][0]']
#                                 )
#
#  conv2d_160 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_159[0][0]']
#
#  batch_normalization_160 (Batch  (None, 64, 128, 64)  256        ['conv2d_160[0][0]']
#  Normalization)
#
#  tf.nn.relu_160 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_160[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_160[0][0]']
#
#  batch_normalization_161 (Batch  (None, 64, 128, 64)  256        ['conv2d_161[0][0]']
#  Normalization)
#
#  tf.nn.relu_161 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_161[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_158[0][0]',
#                                 )                                 'tf.nn.relu_159[0][0]',
#                                                                   'tf.nn.relu_160[0][0]',
#                                                                   'tf.nn.relu_161[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_36[0][0]']
#                                 )
#
#  batch_normalization_162 (Batch  (None, 64, 128, 256  1024       ['conv2d_162[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_162 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_162[0][0]']
#                                 )
#
#  conv2d_163 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_162[0][0]']
#                                 )
#
#  batch_normalization_163 (Batch  (None, 64, 128, 128  512        ['conv2d_163[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_163 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_163[0][0]']
#                                 )
#
#  conv2d_164 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_163[0][0]']
#
#  batch_normalization_164 (Batch  (None, 64, 128, 64)  256        ['conv2d_164[0][0]']
#  Normalization)
#
#  tf.nn.relu_164 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_164[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_164[0][0]']
#
#  batch_normalization_165 (Batch  (None, 64, 128, 64)  256        ['conv2d_165[0][0]']
#  Normalization)
#
#  tf.nn.relu_165 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_165[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_162[0][0]',
#                                 )                                 'tf.nn.relu_163[0][0]',
#                                                                   'tf.nn.relu_164[0][0]',
#                                                                   'tf.nn.relu_165[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_37[0][0]']
#                                 )
#
#  batch_normalization_166 (Batch  (None, 64, 128, 256  1024       ['conv2d_166[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_166 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_166[0][0]']
#                                 )
#
#  conv2d_167 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_166[0][0]']
#                                 )
#
#  batch_normalization_167 (Batch  (None, 64, 128, 128  512        ['conv2d_167[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_167 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_167[0][0]']
#                                 )
#
#  conv2d_168 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_167[0][0]']
#
#  batch_normalization_168 (Batch  (None, 64, 128, 64)  256        ['conv2d_168[0][0]']
#  Normalization)
#
#  tf.nn.relu_168 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_168[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_168[0][0]']
#
#  batch_normalization_169 (Batch  (None, 64, 128, 64)  256        ['conv2d_169[0][0]']
#  Normalization)
#
#  tf.nn.relu_169 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_169[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_166[0][0]',
#                                 )                                 'tf.nn.relu_167[0][0]',
#                                                                   'tf.nn.relu_168[0][0]',
#                                                                   'tf.nn.relu_169[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 64, 128, 512  262656      ['concatenate_38[0][0]']
#                                 )
#
#  batch_normalization_170 (Batch  (None, 64, 128, 512  2048       ['conv2d_170[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_170 (TFOpLambda)    (None, 64, 128, 512  0           ['batch_normalization_170[0][0]']
#                                 )
#
#  conv2d_171 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_170[0][0]']
#
#  batch_normalization_171 (Batch  (None, 32, 64, 256)  1024       ['conv2d_171[0][0]']
#  Normalization)
#
#  tf.nn.relu_171 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_171[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_171[0][0]']
#
#  batch_normalization_172 (Batch  (None, 32, 64, 128)  512        ['conv2d_172[0][0]']
#  Normalization)
#
#  tf.nn.relu_172 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_172[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_172[0][0]']
#
#  batch_normalization_173 (Batch  (None, 32, 64, 128)  512        ['conv2d_173[0][0]']
#  Normalization)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 32, 64, 512)  0          ['tf.nn.relu_170[0][0]']
#  )
#
#  tf.nn.relu_173 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_173[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 32, 64, 1024  0           ['max_pooling2d_14[0][0]',
#                                 )                                 'tf.nn.relu_171[0][0]',
#                                                                   'tf.nn.relu_172[0][0]',
#                                                                   'tf.nn.relu_173[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 32, 64, 512)  524800      ['concatenate_39[0][0]']
#
#  batch_normalization_174 (Batch  (None, 32, 64, 512)  2048       ['conv2d_174[0][0]']
#  Normalization)
#
#  tf.nn.relu_174 (TFOpLambda)    (None, 32, 64, 512)  0           ['batch_normalization_174[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_174[0][0]']
#
#  batch_normalization_175 (Batch  (None, 32, 64, 256)  1024       ['conv2d_175[0][0]']
#  Normalization)
#
#  tf.nn.relu_175 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_175[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_175[0][0]']
#
#  batch_normalization_176 (Batch  (None, 32, 64, 128)  512        ['conv2d_176[0][0]']
#  Normalization)
#
#  tf.nn.relu_176 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_176[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_176[0][0]']
#
#  batch_normalization_177 (Batch  (None, 32, 64, 128)  512        ['conv2d_177[0][0]']
#  Normalization)
#
#  tf.nn.relu_177 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_177[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 32, 64, 1024  0           ['tf.nn.relu_174[0][0]',
#                                 )                                 'tf.nn.relu_175[0][0]',
#                                                                   'tf.nn.relu_176[0][0]',
#                                                                   'tf.nn.relu_177[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 32, 64, 512)  524800      ['concatenate_40[0][0]']
#
#  batch_normalization_178 (Batch  (None, 32, 64, 512)  2048       ['conv2d_178[0][0]']
#  Normalization)
#
#  tf.nn.relu_178 (TFOpLambda)    (None, 32, 64, 512)  0           ['batch_normalization_178[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_178[0][0]']
#
#  batch_normalization_179 (Batch  (None, 32, 64, 256)  1024       ['conv2d_179[0][0]']
#  Normalization)
#
#  tf.nn.relu_179 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_179[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_179[0][0]']
#
#  batch_normalization_180 (Batch  (None, 32, 64, 128)  512        ['conv2d_180[0][0]']
#  Normalization)
#
#  tf.nn.relu_180 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_180[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_180[0][0]']
#
#  batch_normalization_181 (Batch  (None, 32, 64, 128)  512        ['conv2d_181[0][0]']
#  Normalization)
#
#  tf.nn.relu_181 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_181[0][0]']
#
#  concatenate_41 (Concatenate)   (None, 32, 64, 1024  0           ['tf.nn.relu_178[0][0]',
#                                 )                                 'tf.nn.relu_179[0][0]',
#                                                                   'tf.nn.relu_180[0][0]',
#                                                                   'tf.nn.relu_181[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 32, 64, 1024  1049600     ['concatenate_41[0][0]']
#                                 )
#
#  batch_normalization_182 (Batch  (None, 32, 64, 1024  4096       ['conv2d_182[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_182 (TFOpLambda)    (None, 32, 64, 1024  0           ['batch_normalization_182[0][0]']
#                                 )
#
#  global_average_pooling2d_4 (Gl  (None, 1024)        0           ['tf.nn.relu_182[0][0]']
#  obalAveragePooling2D)
#
#  dense_8 (Dense)                (None, 1024)         1049600     ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_9 (Dense)                (None, 1000)         1025000     ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 12,487,464
# Trainable params: 12,471,912
# Non-trainable params: 15,552
# __________________________________________________________________________________________________

# %%
#flops at 1024 x 2048 resolution

from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

from keras_flops import get_flops


# Calculae FLOPS for STDC2 at 1024 X 2028 resolution
flops = get_flops(STDC2, batch_size=1)
print(f"FLOPS: {flops / 10 ** 9:.03} G")
# Out:
# FLOPS: 1.2e+02 G

# %%
#STDC1 semantic segmentation model without detail guidance

# -*- coding: utf-8 -*-


from functools import reduce
import tensorflow as tf
from tensorflow import keras
import numpy as np
import tensorflow.keras.backend as K


#### Custom function for conv2d: conv_block
def conv_block(inputs, conv_type, kernel, kernel_size, strides, padding='same'):
  
      if(conv_type == 'ds'):
        x = tf.keras.layers.SeparableConv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)
      else:
        x = tf.keras.layers.Conv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)  

      x = tf.keras.layers.BatchNormalization()(x)
      x = tf.keras.activations.relu(x)

      return x

def STDC_module(inputs, filters, kernel, s):
    
    
    tchannel1 = filters
    tchannel2 = tchannel1 // 2
    tchannel3 = tchannel1 // 4
    tchannel4 = tchannel1 // 8

    if s==2:
        x1 = conv_block(inputs, 'conv', tchannel2, (1, 1), strides=(1, 1)) #
        x2 = conv_block(x1, 'conv', tchannel3, (3, 3), strides=(s, s))
        x3 = conv_block(x2, 'conv', tchannel4, (3, 3), strides=(1, 1))
        x4 = conv_block(x3, 'conv', tchannel4, (3, 3), strides=(1, 1))

        #Used MaxPooling instead of average pooling
        x1 = tf.keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x1)
    
    else:
        x1 = conv_block(inputs, 'conv', tchannel2, (1, 1), strides=(1, 1))
        x2 = conv_block(x1, 'conv', tchannel3, (3, 3), strides=(1, 1))
        x3 = conv_block(x2, 'conv', tchannel4, (3, 3), strides=(1, 1))
        x4 = conv_block(x3, 'conv', tchannel4, (3, 3), strides=(1, 1))

    
    
    concat = tf.keras.layers.Concatenate()([x1, x2, x3, x4])

    return concat


"""#### STDC_block to control the repetition of STDC modules"""

def STDC_block(inputs, filters, kernel, strides, n):
      x = STDC_module(inputs, filters, kernel, strides)

      for i in range(1, n):
        x = STDC_module(x, filters, kernel, 1)

      return x    

#Feature Fusion Module
def ffm_block(f1, f2, kernel=256):
    ffm = tf.keras.layers.Concatenate()([f1, f2]) #256+128 = 384
    ffm = conv_block(ffm, 'conv', kernel, (1, 1), strides = (1, 1))
    atten = tf.nn.avg_pool2d(ffm, kernel, 1, 'SAME')
    atten = tf.keras.layers.Conv2D(kernel, 1, padding='same', strides = 1)(atten)
    atten = tf.keras.activations.relu(atten)
    
    atten = tf.keras.layers.Conv2D(kernel, 1, padding='same', strides = 1)(atten)
    atten = tf.keras.activations.sigmoid(atten)
    ffm_atten = tf.keras.layers.Multiply()([atten, ffm])
    ffm_out = tf.keras.layers.add([ffm_atten, ffm])
    
    return ffm_out
    
# Attention Refinement Module
def arm_block(inputs, kernel):
  
      #tchannel = tf.keras.backend.int_shape(inputs)[-1] * 2 
      x = conv_block(inputs, 'conv', kernel, (3, 3), strides = (1, 1))
      x = tf.nn.avg_pool2d(x, kernel, 1, 'SAME')
      x = tf.keras.layers.Conv2D(kernel, 1, padding='same', strides = 1)(x)
      x = conv_block(x, 'conv', kernel, (1, 1), strides = (1, 1))  
      x = tf.keras.layers.BatchNormalization()(x)
      x = tf.keras.activations.sigmoid(x)
      x = tf.keras.layers.Multiply()([x, inputs])

      return x   
    

def model(num_classes=19, input_size=(1024, 2048, 3)):

      # Input Layer
      input_layer = tf.keras.layers.Input(shape=input_size, name = 'input_layer')

      ## Step 1: Learning to DownSample
      convx1 = conv_block(input_layer, 'conv', 32, (3, 3), strides = (2, 2))

      convx2 = conv_block(convx1, 'conv', 64, (3, 3), strides = (2, 2))

      #STDC blocks  
      D3 = STDC_block(convx2, 256, (3, 3), strides=2, n=2)

      D4 = STDC_block(D3, 512, (3, 3), strides=2, n=2)

      D5 = STDC_block(D4, 1024, (3, 3), strides=2, n=2)
        
      D5 = tf.nn.avg_pool2d(D5, 1024, 1, 'SAME')
      D5 = conv_block(D5, 'conv', 128, (1, 1), strides = (1, 1))
      D5 = tf.keras.layers.UpSampling2D((1, 1))(D5)
    
      D5_arm = arm_block(D5, 128)
      D5_arm = tf.keras.layers.add([D5_arm, D5])
      D5_up = tf.keras.layers.UpSampling2D((2, 2))(D5_arm)
      D5_up = conv_block(D5_up, 'conv', 128, (3, 3), strides = (1, 1))
      
      D4 = conv_block(D4, 'conv', 128, (1, 1), strides = (1, 1))
      D4_arm = arm_block(D4, 128)
      D4_arm = tf.keras.layers.add([D4_arm, D5_up])
      D4_up = tf.keras.layers.UpSampling2D((2, 2))(D4_arm)
      D4_up = conv_block(D4_up, 'conv', 256, (3, 3), strides = (1, 1))
    
      #feature fusion module
      ffm = ffm_block(D4_up, D3, 256)
      
      #classifier
      classifier = conv_block(ffm, 'conv', 256, (3, 3), strides = (1, 1))
      classifier = tf.keras.layers.Conv2D(num_classes, 1, padding='same', strides = 1)(classifier)
        
      classifier = tf.keras.layers.Dropout(0.3)(classifier)
      classifier = tf.keras.layers.UpSampling2D((8, 8))(classifier)
      classifier = tf.dtypes.cast(classifier, tf.float32)
      classifier = tf.keras.activations.softmax(classifier)

      STDC1_seg = tf.keras.Model(inputs = input_layer , outputs = classifier, name = 'STDC1_seg')

      return STDC1_seg

# %%
STDC1_seg = model(num_classes=19, input_size=(1024, 2048, 3))
STDC1_seg.summary()
# Out:
# Model: "STDC1_seg"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 1024, 2048,  0           []
#                                  3)]
#
#  conv2d_305 (Conv2D)            (None, 512, 1024, 3  896         ['input_layer[0][0]']
#                                 2)
#
#  batch_normalization_302 (Batch  (None, 512, 1024, 3  128        ['conv2d_305[0][0]']
#  Normalization)                 2)
#
#  tf.nn.relu_301 (TFOpLambda)    (None, 512, 1024, 3  0           ['batch_normalization_302[0][0]']
#                                 2)
#
#  conv2d_306 (Conv2D)            (None, 256, 512, 64  18496       ['tf.nn.relu_301[0][0]']
#                                 )
#
#  batch_normalization_303 (Batch  (None, 256, 512, 64  256        ['conv2d_306[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_302 (TFOpLambda)    (None, 256, 512, 64  0           ['batch_normalization_303[0][0]']
#                                 )
#
#  conv2d_307 (Conv2D)            (None, 256, 512, 12  8320        ['tf.nn.relu_302[0][0]']
#                                 8)
#
#  batch_normalization_304 (Batch  (None, 256, 512, 12  512        ['conv2d_307[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_303 (TFOpLambda)    (None, 256, 512, 12  0           ['batch_normalization_304[0][0]']
#                                 8)
#
#  conv2d_308 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_303[0][0]']
#                                 )
#
#  batch_normalization_305 (Batch  (None, 128, 256, 64  256        ['conv2d_308[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_304 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_305[0][0]']
#                                 )
#
#  conv2d_309 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_304[0][0]']
#                                 )
#
#  batch_normalization_306 (Batch  (None, 128, 256, 32  128        ['conv2d_309[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_305 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_306[0][0]']
#                                 )
#
#  conv2d_310 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_305[0][0]']
#                                 )
#
#  batch_normalization_307 (Batch  (None, 128, 256, 32  128        ['conv2d_310[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_27 (MaxPooling2D  (None, 128, 256, 12  0          ['tf.nn.relu_303[0][0]']
#  )                              8)
#
#  tf.nn.relu_306 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_307[0][0]']
#                                 )
#
#  concatenate_67 (Concatenate)   (None, 128, 256, 25  0           ['max_pooling2d_27[0][0]',
#                                 6)                                'tf.nn.relu_304[0][0]',
#                                                                   'tf.nn.relu_305[0][0]',
#                                                                   'tf.nn.relu_306[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 128, 256, 12  32896       ['concatenate_67[0][0]']
#                                 8)
#
#  batch_normalization_308 (Batch  (None, 128, 256, 12  512        ['conv2d_311[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_307 (TFOpLambda)    (None, 128, 256, 12  0           ['batch_normalization_308[0][0]']
#                                 8)
#
#  conv2d_312 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_307[0][0]']
#                                 )
#
#  batch_normalization_309 (Batch  (None, 128, 256, 64  256        ['conv2d_312[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_308 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_309[0][0]']
#                                 )
#
#  conv2d_313 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_308[0][0]']
#                                 )
#
#  batch_normalization_310 (Batch  (None, 128, 256, 32  128        ['conv2d_313[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_309 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_310[0][0]']
#                                 )
#
#  conv2d_314 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_309[0][0]']
#                                 )
#
#  batch_normalization_311 (Batch  (None, 128, 256, 32  128        ['conv2d_314[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_310 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_311[0][0]']
#                                 )
#
#  concatenate_68 (Concatenate)   (None, 128, 256, 25  0           ['tf.nn.relu_307[0][0]',
#                                 6)                                'tf.nn.relu_308[0][0]',
#                                                                   'tf.nn.relu_309[0][0]',
#                                                                   'tf.nn.relu_310[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 128, 256, 25  65792       ['concatenate_68[0][0]']
#                                 6)
#
#  batch_normalization_312 (Batch  (None, 128, 256, 25  1024       ['conv2d_315[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_311 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_312[0][0]']
#                                 6)
#
#  conv2d_316 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_311[0][0]']
#                                 )
#
#  batch_normalization_313 (Batch  (None, 64, 128, 128  512        ['conv2d_316[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_312 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_313[0][0]']
#                                 )
#
#  conv2d_317 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_312[0][0]']
#
#  batch_normalization_314 (Batch  (None, 64, 128, 64)  256        ['conv2d_317[0][0]']
#  Normalization)
#
#  tf.nn.relu_313 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_314[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_313[0][0]']
#
#  batch_normalization_315 (Batch  (None, 64, 128, 64)  256        ['conv2d_318[0][0]']
#  Normalization)
#
#  max_pooling2d_28 (MaxPooling2D  (None, 64, 128, 256  0          ['tf.nn.relu_311[0][0]']
#  )                              )
#
#  tf.nn.relu_314 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_315[0][0]']
#
#  concatenate_69 (Concatenate)   (None, 64, 128, 512  0           ['max_pooling2d_28[0][0]',
#                                 )                                 'tf.nn.relu_312[0][0]',
#                                                                   'tf.nn.relu_313[0][0]',
#                                                                   'tf.nn.relu_314[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_69[0][0]']
#                                 )
#
#  batch_normalization_316 (Batch  (None, 64, 128, 256  1024       ['conv2d_319[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_315 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_316[0][0]']
#                                 )
#
#  conv2d_320 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_315[0][0]']
#                                 )
#
#  batch_normalization_317 (Batch  (None, 64, 128, 128  512        ['conv2d_320[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_316 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_317[0][0]']
#                                 )
#
#  conv2d_321 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_316[0][0]']
#
#  batch_normalization_318 (Batch  (None, 64, 128, 64)  256        ['conv2d_321[0][0]']
#  Normalization)
#
#  tf.nn.relu_317 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_318[0][0]']
#
#  conv2d_322 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_317[0][0]']
#
#  batch_normalization_319 (Batch  (None, 64, 128, 64)  256        ['conv2d_322[0][0]']
#  Normalization)
#
#  tf.nn.relu_318 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_319[0][0]']
#
#  concatenate_70 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_315[0][0]',
#                                 )                                 'tf.nn.relu_316[0][0]',
#                                                                   'tf.nn.relu_317[0][0]',
#                                                                   'tf.nn.relu_318[0][0]']
#
#  conv2d_323 (Conv2D)            (None, 64, 128, 512  262656      ['concatenate_70[0][0]']
#                                 )
#
#  batch_normalization_320 (Batch  (None, 64, 128, 512  2048       ['conv2d_323[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_319 (TFOpLambda)    (None, 64, 128, 512  0           ['batch_normalization_320[0][0]']
#                                 )
#
#  conv2d_324 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_319[0][0]']
#
#  batch_normalization_321 (Batch  (None, 32, 64, 256)  1024       ['conv2d_324[0][0]']
#  Normalization)
#
#  tf.nn.relu_320 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_321[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_320[0][0]']
#
#  batch_normalization_322 (Batch  (None, 32, 64, 128)  512        ['conv2d_325[0][0]']
#  Normalization)
#
#  tf.nn.relu_321 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_322[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_321[0][0]']
#
#  batch_normalization_323 (Batch  (None, 32, 64, 128)  512        ['conv2d_326[0][0]']
#  Normalization)
#
#  max_pooling2d_29 (MaxPooling2D  (None, 32, 64, 512)  0          ['tf.nn.relu_319[0][0]']
#  )
#
#  tf.nn.relu_322 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_323[0][0]']
#
#  concatenate_71 (Concatenate)   (None, 32, 64, 1024  0           ['max_pooling2d_29[0][0]',
#                                 )                                 'tf.nn.relu_320[0][0]',
#                                                                   'tf.nn.relu_321[0][0]',
#                                                                   'tf.nn.relu_322[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 32, 64, 512)  524800      ['concatenate_71[0][0]']
#
#  batch_normalization_324 (Batch  (None, 32, 64, 512)  2048       ['conv2d_327[0][0]']
#  Normalization)
#
#  tf.nn.relu_323 (TFOpLambda)    (None, 32, 64, 512)  0           ['batch_normalization_324[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_323[0][0]']
#
#  batch_normalization_325 (Batch  (None, 32, 64, 256)  1024       ['conv2d_328[0][0]']
#  Normalization)
#
#  tf.nn.relu_324 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_325[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_324[0][0]']
#
#  batch_normalization_326 (Batch  (None, 32, 64, 128)  512        ['conv2d_329[0][0]']
#  Normalization)
#
#  tf.nn.relu_325 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_326[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_325[0][0]']
#
#  batch_normalization_327 (Batch  (None, 32, 64, 128)  512        ['conv2d_330[0][0]']
#  Normalization)
#
#  tf.nn.relu_326 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_327[0][0]']
#
#  concatenate_72 (Concatenate)   (None, 32, 64, 1024  0           ['tf.nn.relu_323[0][0]',
#                                 )                                 'tf.nn.relu_324[0][0]',
#                                                                   'tf.nn.relu_325[0][0]',
#                                                                   'tf.nn.relu_326[0][0]']
#
#  tf.nn.avg_pool2d_5 (TFOpLambda  (None, 32, 64, 1024  0          ['concatenate_72[0][0]']
#  )                              )
#
#  conv2d_331 (Conv2D)            (None, 32, 64, 128)  131200      ['tf.nn.avg_pool2d_5[0][0]']
#
#  batch_normalization_328 (Batch  (None, 32, 64, 128)  512        ['conv2d_331[0][0]']
#  Normalization)
#
#  tf.nn.relu_327 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_328[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 32, 64, 128)  0          ['tf.nn.relu_327[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 32, 64, 128)  147584      ['up_sampling2d_5[0][0]']
#
#  batch_normalization_329 (Batch  (None, 32, 64, 128)  512        ['conv2d_332[0][0]']
#  Normalization)
#
#  conv2d_336 (Conv2D)            (None, 64, 128, 128  65664       ['concatenate_70[0][0]']
#                                 )
#
#  tf.nn.relu_328 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_329[0][0]']
#
#  batch_normalization_333 (Batch  (None, 64, 128, 128  512        ['conv2d_336[0][0]']
#  Normalization)                 )
#
#  tf.nn.avg_pool2d_6 (TFOpLambda  (None, 32, 64, 128)  0          ['tf.nn.relu_328[0][0]']
#  )
#
#  tf.nn.relu_331 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_333[0][0]']
#                                 )
#
#  conv2d_333 (Conv2D)            (None, 32, 64, 128)  16512       ['tf.nn.avg_pool2d_6[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 64, 128, 128  147584      ['tf.nn.relu_331[0][0]']
#                                 )
#
#  conv2d_334 (Conv2D)            (None, 32, 64, 128)  16512       ['conv2d_333[0][0]']
#
#  batch_normalization_334 (Batch  (None, 64, 128, 128  512        ['conv2d_337[0][0]']
#  Normalization)                 )
#
#  batch_normalization_330 (Batch  (None, 32, 64, 128)  512        ['conv2d_334[0][0]']
#  Normalization)
#
#  tf.nn.relu_332 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_334[0][0]']
#                                 )
#
#  tf.nn.relu_329 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_330[0][0]']
#
#  tf.nn.avg_pool2d_7 (TFOpLambda  (None, 64, 128, 128  0          ['tf.nn.relu_332[0][0]']
#  )                              )
#
#  batch_normalization_331 (Batch  (None, 32, 64, 128)  512        ['tf.nn.relu_329[0][0]']
#  Normalization)
#
#  conv2d_338 (Conv2D)            (None, 64, 128, 128  16512       ['tf.nn.avg_pool2d_7[0][0]']
#                                 )
#
#  tf.math.sigmoid_3 (TFOpLambda)  (None, 32, 64, 128)  0          ['batch_normalization_331[0][0]']
#
#  conv2d_339 (Conv2D)            (None, 64, 128, 128  16512       ['conv2d_338[0][0]']
#                                 )
#
#  multiply_3 (Multiply)          (None, 32, 64, 128)  0           ['tf.math.sigmoid_3[0][0]',
#                                                                   'up_sampling2d_5[0][0]']
#
#  batch_normalization_335 (Batch  (None, 64, 128, 128  512        ['conv2d_339[0][0]']
#  Normalization)                 )
#
#  add_3 (Add)                    (None, 32, 64, 128)  0           ['multiply_3[0][0]',
#                                                                   'up_sampling2d_5[0][0]']
#
#  tf.nn.relu_333 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_335[0][0]']
#                                 )
#
#  up_sampling2d_6 (UpSampling2D)  (None, 64, 128, 128  0          ['add_3[0][0]']
#                                 )
#
#  batch_normalization_336 (Batch  (None, 64, 128, 128  512        ['tf.nn.relu_333[0][0]']
#  Normalization)                 )
#
#  conv2d_335 (Conv2D)            (None, 64, 128, 128  147584      ['up_sampling2d_6[0][0]']
#                                 )
#
#  tf.math.sigmoid_4 (TFOpLambda)  (None, 64, 128, 128  0          ['batch_normalization_336[0][0]']
#                                 )
#
#  batch_normalization_332 (Batch  (None, 64, 128, 128  512        ['conv2d_335[0][0]']
#  Normalization)                 )
#
#  multiply_4 (Multiply)          (None, 64, 128, 128  0           ['tf.math.sigmoid_4[0][0]',
#                                 )                                 'tf.nn.relu_331[0][0]']
#
#  tf.nn.relu_330 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_332[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 64, 128, 128  0           ['multiply_4[0][0]',
#                                 )                                 'tf.nn.relu_330[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 128, 256, 12  0          ['add_4[0][0]']
#                                 8)
#
#  conv2d_340 (Conv2D)            (None, 128, 256, 25  295168      ['up_sampling2d_7[0][0]']
#                                 6)
#
#  batch_normalization_337 (Batch  (None, 128, 256, 25  1024       ['conv2d_340[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_334 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_337[0][0]']
#                                 6)
#
#  concatenate_73 (Concatenate)   (None, 128, 256, 51  0           ['tf.nn.relu_334[0][0]',
#                                 2)                                'concatenate_68[0][0]']
#
#  conv2d_341 (Conv2D)            (None, 128, 256, 25  131328      ['concatenate_73[0][0]']
#                                 6)
#
#  batch_normalization_338 (Batch  (None, 128, 256, 25  1024       ['conv2d_341[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_335 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_338[0][0]']
#                                 6)
#
#  tf.nn.avg_pool2d_8 (TFOpLambda  (None, 128, 256, 25  0          ['tf.nn.relu_335[0][0]']
#  )                              6)
#
#  conv2d_342 (Conv2D)            (None, 128, 256, 25  65792       ['tf.nn.avg_pool2d_8[0][0]']
#                                 6)
#
#  tf.nn.relu_336 (TFOpLambda)    (None, 128, 256, 25  0           ['conv2d_342[0][0]']
#                                 6)
#
#  conv2d_343 (Conv2D)            (None, 128, 256, 25  65792       ['tf.nn.relu_336[0][0]']
#                                 6)
#
#  tf.math.sigmoid_5 (TFOpLambda)  (None, 128, 256, 25  0          ['conv2d_343[0][0]']
#                                 6)
#
#  multiply_5 (Multiply)          (None, 128, 256, 25  0           ['tf.math.sigmoid_5[0][0]',
#                                 6)                                'tf.nn.relu_335[0][0]']
#
#  add_5 (Add)                    (None, 128, 256, 25  0           ['multiply_5[0][0]',
#                                 6)                                'tf.nn.relu_335[0][0]']
#
#  conv2d_344 (Conv2D)            (None, 128, 256, 25  590080      ['add_5[0][0]']
#                                 6)
#
#  batch_normalization_339 (Batch  (None, 128, 256, 25  1024       ['conv2d_344[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_337 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_339[0][0]']
#                                 6)
#
#  conv2d_345 (Conv2D)            (None, 128, 256, 19  4883        ['tf.nn.relu_337[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 256, 19  0           ['conv2d_345[0][0]']
#                                 )
#
#  up_sampling2d_8 (UpSampling2D)  (None, 1024, 2048,   0          ['dropout_1[0][0]']
#                                 19)
#
#  tf.cast_1 (TFOpLambda)         (None, 1024, 2048,   0           ['up_sampling2d_8[0][0]']
#                                 19)
#
#  tf.nn.softmax_1 (TFOpLambda)   (None, 1024, 2048,   0           ['tf.cast_1[0][0]']
#                                 19)
#
# ==================================================================================================
# Total params: 7,185,875
# Trainable params: 7,174,675
# Non-trainable params: 11,200
# __________________________________________________________________________________________________

# %%
#flops at 1024 x 2048x1536 resolution

from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

from keras_flops import get_flops


# Calculae FLOPS
flops = get_flops(STDC1_seg, batch_size=1)
print(f"FLOPS: {flops / 10 ** 9:.03} G")
# Out:
# FLOPS: 2.92e+03 G

# %%
#STDC2 semantic segmentation model without detail guidance

# -*- coding: utf-8 -*-


from functools import reduce
import tensorflow as tf
from tensorflow import keras
import numpy as np
import tensorflow.keras.backend as K


#### Custom function for conv2d: conv_block
def conv_block(inputs, conv_type, kernel, kernel_size, strides, padding='same'):
  
      if(conv_type == 'ds'):
        x = tf.keras.layers.SeparableConv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)
      else:
        x = tf.keras.layers.Conv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)  

      x = tf.keras.layers.BatchNormalization()(x)
      x = tf.keras.activations.relu(x)

      return x

def STDC_module(inputs, filters, kernel, s):
    
    
    tchannel1 = filters
    tchannel2 = tchannel1 // 2
    tchannel3 = tchannel1 // 4
    tchannel4 = tchannel1 // 8

    if s==2:
        x1 = conv_block(inputs, 'conv', tchannel2, (1, 1), strides=(1, 1)) #
        x2 = conv_block(x1, 'conv', tchannel3, (3, 3), strides=(s, s))
        x3 = conv_block(x2, 'conv', tchannel4, (3, 3), strides=(1, 1))
        x4 = conv_block(x3, 'conv', tchannel4, (3, 3), strides=(1, 1))

        #Used MaxPooling instead of average pooling
        x1 = tf.keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x1)
    
    else:
        x1 = conv_block(inputs, 'conv', tchannel2, (1, 1), strides=(1, 1))
        x2 = conv_block(x1, 'conv', tchannel3, (3, 3), strides=(1, 1))
        x3 = conv_block(x2, 'conv', tchannel4, (3, 3), strides=(1, 1))
        x4 = conv_block(x3, 'conv', tchannel4, (3, 3), strides=(1, 1))

    
    
    concat = tf.keras.layers.Concatenate()([x1, x2, x3, x4])

    return concat


"""#### STDC_block to control the repetition of STDC modules"""

def STDC_block(inputs, filters, kernel, strides, n):
      x = STDC_module(inputs, filters, kernel, strides)

      for i in range(1, n):
        x = STDC_module(x, filters, kernel, 1)

      return x    

#Feature Fusion Module
def ffm_block(f1, f2, kernel=256):
    ffm = tf.keras.layers.Concatenate()([f1, f2]) #256+128 = 384
    ffm = conv_block(ffm, 'conv', kernel, (1, 1), strides = (1, 1))
    atten = tf.nn.avg_pool2d(ffm, kernel, 1, 'SAME')
    atten = tf.keras.layers.Conv2D(kernel, 1, padding='same', strides = 1)(atten)
    atten = tf.keras.activations.relu(atten)
    
    atten = tf.keras.layers.Conv2D(kernel, 1, padding='same', strides = 1)(atten)
    atten = tf.keras.activations.sigmoid(atten)
    ffm_atten = tf.keras.layers.Multiply()([atten, ffm])
    ffm_out = tf.keras.layers.add([ffm_atten, ffm])
    
    return ffm_out
    
# Attention Refinement Module
def arm_block(inputs, kernel):
  
      #tchannel = tf.keras.backend.int_shape(inputs)[-1] * 2 
      x = conv_block(inputs, 'conv', kernel, (3, 3), strides = (1, 1))
      x = tf.nn.avg_pool2d(x, kernel, 1, 'SAME')
      x = tf.keras.layers.Conv2D(kernel, 1, padding='same', strides = 1)(x)
      x = conv_block(x, 'conv', kernel, (1, 1), strides = (1, 1))  
      x = tf.keras.layers.BatchNormalization()(x)
      x = tf.keras.activations.sigmoid(x)
      x = tf.keras.layers.Multiply()([x, inputs])

      return x   
    

def model(num_classes=19, input_size=(1024, 2048, 3)):

      # Input Layer
      input_layer = tf.keras.layers.Input(shape=input_size, name = 'input_layer')

      ## Step 1: Learning to DownSample
      convx1 = conv_block(input_layer, 'conv', 32, (3, 3), strides = (2, 2))

      convx2 = conv_block(convx1, 'conv', 64, (3, 3), strides = (2, 2))

      #STDC blocks  
      D3 = STDC_block(convx2, 256, (3, 3), strides=2, n=4)

      D4 = STDC_block(D3, 512, (3, 3), strides=2, n=5)

      D5 = STDC_block(D4, 1024, (3, 3), strides=2, n=3)
        
      D5 = tf.nn.avg_pool2d(D5, 1024, 1, 'SAME')
      D5 = conv_block(D5, 'conv', 128, (1, 1), strides = (1, 1))
      D5 = tf.keras.layers.UpSampling2D((1, 1))(D5)
    
      D5_arm = arm_block(D5, 128)
      D5_arm = tf.keras.layers.add([D5_arm, D5])
      D5_up = tf.keras.layers.UpSampling2D((2, 2))(D5_arm)
      D5_up = conv_block(D5_up, 'conv', 128, (3, 3), strides = (1, 1))
      
      D4 = conv_block(D4, 'conv', 128, (1, 1), strides = (1, 1))
      D4_arm = arm_block(D4, 128)
      D4_arm = tf.keras.layers.add([D4_arm, D5_up])
      D4_up = tf.keras.layers.UpSampling2D((2, 2))(D4_arm)
      D4_up = conv_block(D4_up, 'conv', 256, (3, 3), strides = (1, 1))
    
      #feature fusion module
      ffm = ffm_block(D4_up, D3, 256)
      
      #classifier
      classifier = conv_block(ffm, 'conv', 256, (3, 3), strides = (1, 1))
      classifier = tf.keras.layers.Conv2D(num_classes, 1, padding='same', strides = 1)(classifier)
        
      classifier = tf.keras.layers.Dropout(0.3)(classifier)
      classifier = tf.keras.layers.UpSampling2D((8, 8))(classifier)
      classifier = tf.dtypes.cast(classifier, tf.float32)
      classifier = tf.keras.activations.softmax(classifier)

      STDC2_seg = tf.keras.Model(inputs = input_layer , outputs = classifier, name = 'STDC2_seg')

      return STDC2_seg

# %%
STDC2_seg = model(num_classes=19, input_size=(1024, 2048, 3))
STDC2_seg.summary()
# Out:
# Model: "STDC2_seg"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 1024, 2048,  0           []
#                                  3)]
#
#  conv2d_346 (Conv2D)            (None, 512, 1024, 3  896         ['input_layer[0][0]']
#                                 2)
#
#  batch_normalization_340 (Batch  (None, 512, 1024, 3  128        ['conv2d_346[0][0]']
#  Normalization)                 2)
#
#  tf.nn.relu_338 (TFOpLambda)    (None, 512, 1024, 3  0           ['batch_normalization_340[0][0]']
#                                 2)
#
#  conv2d_347 (Conv2D)            (None, 256, 512, 64  18496       ['tf.nn.relu_338[0][0]']
#                                 )
#
#  batch_normalization_341 (Batch  (None, 256, 512, 64  256        ['conv2d_347[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_339 (TFOpLambda)    (None, 256, 512, 64  0           ['batch_normalization_341[0][0]']
#                                 )
#
#  conv2d_348 (Conv2D)            (None, 256, 512, 12  8320        ['tf.nn.relu_339[0][0]']
#                                 8)
#
#  batch_normalization_342 (Batch  (None, 256, 512, 12  512        ['conv2d_348[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_340 (TFOpLambda)    (None, 256, 512, 12  0           ['batch_normalization_342[0][0]']
#                                 8)
#
#  conv2d_349 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_340[0][0]']
#                                 )
#
#  batch_normalization_343 (Batch  (None, 128, 256, 64  256        ['conv2d_349[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_341 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_343[0][0]']
#                                 )
#
#  conv2d_350 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_341[0][0]']
#                                 )
#
#  batch_normalization_344 (Batch  (None, 128, 256, 32  128        ['conv2d_350[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_342 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_344[0][0]']
#                                 )
#
#  conv2d_351 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_342[0][0]']
#                                 )
#
#  batch_normalization_345 (Batch  (None, 128, 256, 32  128        ['conv2d_351[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_30 (MaxPooling2D  (None, 128, 256, 12  0          ['tf.nn.relu_340[0][0]']
#  )                              8)
#
#  tf.nn.relu_343 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_345[0][0]']
#                                 )
#
#  concatenate_74 (Concatenate)   (None, 128, 256, 25  0           ['max_pooling2d_30[0][0]',
#                                 6)                                'tf.nn.relu_341[0][0]',
#                                                                   'tf.nn.relu_342[0][0]',
#                                                                   'tf.nn.relu_343[0][0]']
#
#  conv2d_352 (Conv2D)            (None, 128, 256, 12  32896       ['concatenate_74[0][0]']
#                                 8)
#
#  batch_normalization_346 (Batch  (None, 128, 256, 12  512        ['conv2d_352[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_344 (TFOpLambda)    (None, 128, 256, 12  0           ['batch_normalization_346[0][0]']
#                                 8)
#
#  conv2d_353 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_344[0][0]']
#                                 )
#
#  batch_normalization_347 (Batch  (None, 128, 256, 64  256        ['conv2d_353[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_345 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_347[0][0]']
#                                 )
#
#  conv2d_354 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_345[0][0]']
#                                 )
#
#  batch_normalization_348 (Batch  (None, 128, 256, 32  128        ['conv2d_354[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_346 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_348[0][0]']
#                                 )
#
#  conv2d_355 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_346[0][0]']
#                                 )
#
#  batch_normalization_349 (Batch  (None, 128, 256, 32  128        ['conv2d_355[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_347 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_349[0][0]']
#                                 )
#
#  concatenate_75 (Concatenate)   (None, 128, 256, 25  0           ['tf.nn.relu_344[0][0]',
#                                 6)                                'tf.nn.relu_345[0][0]',
#                                                                   'tf.nn.relu_346[0][0]',
#                                                                   'tf.nn.relu_347[0][0]']
#
#  conv2d_356 (Conv2D)            (None, 128, 256, 12  32896       ['concatenate_75[0][0]']
#                                 8)
#
#  batch_normalization_350 (Batch  (None, 128, 256, 12  512        ['conv2d_356[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_348 (TFOpLambda)    (None, 128, 256, 12  0           ['batch_normalization_350[0][0]']
#                                 8)
#
#  conv2d_357 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_348[0][0]']
#                                 )
#
#  batch_normalization_351 (Batch  (None, 128, 256, 64  256        ['conv2d_357[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_349 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_351[0][0]']
#                                 )
#
#  conv2d_358 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_349[0][0]']
#                                 )
#
#  batch_normalization_352 (Batch  (None, 128, 256, 32  128        ['conv2d_358[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_350 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_352[0][0]']
#                                 )
#
#  conv2d_359 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_350[0][0]']
#                                 )
#
#  batch_normalization_353 (Batch  (None, 128, 256, 32  128        ['conv2d_359[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_351 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_353[0][0]']
#                                 )
#
#  concatenate_76 (Concatenate)   (None, 128, 256, 25  0           ['tf.nn.relu_348[0][0]',
#                                 6)                                'tf.nn.relu_349[0][0]',
#                                                                   'tf.nn.relu_350[0][0]',
#                                                                   'tf.nn.relu_351[0][0]']
#
#  conv2d_360 (Conv2D)            (None, 128, 256, 12  32896       ['concatenate_76[0][0]']
#                                 8)
#
#  batch_normalization_354 (Batch  (None, 128, 256, 12  512        ['conv2d_360[0][0]']
#  Normalization)                 8)
#
#  tf.nn.relu_352 (TFOpLambda)    (None, 128, 256, 12  0           ['batch_normalization_354[0][0]']
#                                 8)
#
#  conv2d_361 (Conv2D)            (None, 128, 256, 64  73792       ['tf.nn.relu_352[0][0]']
#                                 )
#
#  batch_normalization_355 (Batch  (None, 128, 256, 64  256        ['conv2d_361[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_353 (TFOpLambda)    (None, 128, 256, 64  0           ['batch_normalization_355[0][0]']
#                                 )
#
#  conv2d_362 (Conv2D)            (None, 128, 256, 32  18464       ['tf.nn.relu_353[0][0]']
#                                 )
#
#  batch_normalization_356 (Batch  (None, 128, 256, 32  128        ['conv2d_362[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_354 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_356[0][0]']
#                                 )
#
#  conv2d_363 (Conv2D)            (None, 128, 256, 32  9248        ['tf.nn.relu_354[0][0]']
#                                 )
#
#  batch_normalization_357 (Batch  (None, 128, 256, 32  128        ['conv2d_363[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_355 (TFOpLambda)    (None, 128, 256, 32  0           ['batch_normalization_357[0][0]']
#                                 )
#
#  concatenate_77 (Concatenate)   (None, 128, 256, 25  0           ['tf.nn.relu_352[0][0]',
#                                 6)                                'tf.nn.relu_353[0][0]',
#                                                                   'tf.nn.relu_354[0][0]',
#                                                                   'tf.nn.relu_355[0][0]']
#
#  conv2d_364 (Conv2D)            (None, 128, 256, 25  65792       ['concatenate_77[0][0]']
#                                 6)
#
#  batch_normalization_358 (Batch  (None, 128, 256, 25  1024       ['conv2d_364[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_356 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_358[0][0]']
#                                 6)
#
#  conv2d_365 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_356[0][0]']
#                                 )
#
#  batch_normalization_359 (Batch  (None, 64, 128, 128  512        ['conv2d_365[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_357 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_359[0][0]']
#                                 )
#
#  conv2d_366 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_357[0][0]']
#
#  batch_normalization_360 (Batch  (None, 64, 128, 64)  256        ['conv2d_366[0][0]']
#  Normalization)
#
#  tf.nn.relu_358 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_360[0][0]']
#
#  conv2d_367 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_358[0][0]']
#
#  batch_normalization_361 (Batch  (None, 64, 128, 64)  256        ['conv2d_367[0][0]']
#  Normalization)
#
#  max_pooling2d_31 (MaxPooling2D  (None, 64, 128, 256  0          ['tf.nn.relu_356[0][0]']
#  )                              )
#
#  tf.nn.relu_359 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_361[0][0]']
#
#  concatenate_78 (Concatenate)   (None, 64, 128, 512  0           ['max_pooling2d_31[0][0]',
#                                 )                                 'tf.nn.relu_357[0][0]',
#                                                                   'tf.nn.relu_358[0][0]',
#                                                                   'tf.nn.relu_359[0][0]']
#
#  conv2d_368 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_78[0][0]']
#                                 )
#
#  batch_normalization_362 (Batch  (None, 64, 128, 256  1024       ['conv2d_368[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_360 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_362[0][0]']
#                                 )
#
#  conv2d_369 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_360[0][0]']
#                                 )
#
#  batch_normalization_363 (Batch  (None, 64, 128, 128  512        ['conv2d_369[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_361 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_363[0][0]']
#                                 )
#
#  conv2d_370 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_361[0][0]']
#
#  batch_normalization_364 (Batch  (None, 64, 128, 64)  256        ['conv2d_370[0][0]']
#  Normalization)
#
#  tf.nn.relu_362 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_364[0][0]']
#
#  conv2d_371 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_362[0][0]']
#
#  batch_normalization_365 (Batch  (None, 64, 128, 64)  256        ['conv2d_371[0][0]']
#  Normalization)
#
#  tf.nn.relu_363 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_365[0][0]']
#
#  concatenate_79 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_360[0][0]',
#                                 )                                 'tf.nn.relu_361[0][0]',
#                                                                   'tf.nn.relu_362[0][0]',
#                                                                   'tf.nn.relu_363[0][0]']
#
#  conv2d_372 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_79[0][0]']
#                                 )
#
#  batch_normalization_366 (Batch  (None, 64, 128, 256  1024       ['conv2d_372[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_364 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_366[0][0]']
#                                 )
#
#  conv2d_373 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_364[0][0]']
#                                 )
#
#  batch_normalization_367 (Batch  (None, 64, 128, 128  512        ['conv2d_373[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_365 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_367[0][0]']
#                                 )
#
#  conv2d_374 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_365[0][0]']
#
#  batch_normalization_368 (Batch  (None, 64, 128, 64)  256        ['conv2d_374[0][0]']
#  Normalization)
#
#  tf.nn.relu_366 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_368[0][0]']
#
#  conv2d_375 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_366[0][0]']
#
#  batch_normalization_369 (Batch  (None, 64, 128, 64)  256        ['conv2d_375[0][0]']
#  Normalization)
#
#  tf.nn.relu_367 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_369[0][0]']
#
#  concatenate_80 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_364[0][0]',
#                                 )                                 'tf.nn.relu_365[0][0]',
#                                                                   'tf.nn.relu_366[0][0]',
#                                                                   'tf.nn.relu_367[0][0]']
#
#  conv2d_376 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_80[0][0]']
#                                 )
#
#  batch_normalization_370 (Batch  (None, 64, 128, 256  1024       ['conv2d_376[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_368 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_370[0][0]']
#                                 )
#
#  conv2d_377 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_368[0][0]']
#                                 )
#
#  batch_normalization_371 (Batch  (None, 64, 128, 128  512        ['conv2d_377[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_369 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_371[0][0]']
#                                 )
#
#  conv2d_378 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_369[0][0]']
#
#  batch_normalization_372 (Batch  (None, 64, 128, 64)  256        ['conv2d_378[0][0]']
#  Normalization)
#
#  tf.nn.relu_370 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_372[0][0]']
#
#  conv2d_379 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_370[0][0]']
#
#  batch_normalization_373 (Batch  (None, 64, 128, 64)  256        ['conv2d_379[0][0]']
#  Normalization)
#
#  tf.nn.relu_371 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_373[0][0]']
#
#  concatenate_81 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_368[0][0]',
#                                 )                                 'tf.nn.relu_369[0][0]',
#                                                                   'tf.nn.relu_370[0][0]',
#                                                                   'tf.nn.relu_371[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 64, 128, 256  131328      ['concatenate_81[0][0]']
#                                 )
#
#  batch_normalization_374 (Batch  (None, 64, 128, 256  1024       ['conv2d_380[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_372 (TFOpLambda)    (None, 64, 128, 256  0           ['batch_normalization_374[0][0]']
#                                 )
#
#  conv2d_381 (Conv2D)            (None, 64, 128, 128  295040      ['tf.nn.relu_372[0][0]']
#                                 )
#
#  batch_normalization_375 (Batch  (None, 64, 128, 128  512        ['conv2d_381[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_373 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_375[0][0]']
#                                 )
#
#  conv2d_382 (Conv2D)            (None, 64, 128, 64)  73792       ['tf.nn.relu_373[0][0]']
#
#  batch_normalization_376 (Batch  (None, 64, 128, 64)  256        ['conv2d_382[0][0]']
#  Normalization)
#
#  tf.nn.relu_374 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_376[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 64, 128, 64)  36928       ['tf.nn.relu_374[0][0]']
#
#  batch_normalization_377 (Batch  (None, 64, 128, 64)  256        ['conv2d_383[0][0]']
#  Normalization)
#
#  tf.nn.relu_375 (TFOpLambda)    (None, 64, 128, 64)  0           ['batch_normalization_377[0][0]']
#
#  concatenate_82 (Concatenate)   (None, 64, 128, 512  0           ['tf.nn.relu_372[0][0]',
#                                 )                                 'tf.nn.relu_373[0][0]',
#                                                                   'tf.nn.relu_374[0][0]',
#                                                                   'tf.nn.relu_375[0][0]']
#
#  conv2d_384 (Conv2D)            (None, 64, 128, 512  262656      ['concatenate_82[0][0]']
#                                 )
#
#  batch_normalization_378 (Batch  (None, 64, 128, 512  2048       ['conv2d_384[0][0]']
#  Normalization)                 )
#
#  tf.nn.relu_376 (TFOpLambda)    (None, 64, 128, 512  0           ['batch_normalization_378[0][0]']
#                                 )
#
#  conv2d_385 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_376[0][0]']
#
#  batch_normalization_379 (Batch  (None, 32, 64, 256)  1024       ['conv2d_385[0][0]']
#  Normalization)
#
#  tf.nn.relu_377 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_379[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_377[0][0]']
#
#  batch_normalization_380 (Batch  (None, 32, 64, 128)  512        ['conv2d_386[0][0]']
#  Normalization)
#
#  tf.nn.relu_378 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_380[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_378[0][0]']
#
#  batch_normalization_381 (Batch  (None, 32, 64, 128)  512        ['conv2d_387[0][0]']
#  Normalization)
#
#  max_pooling2d_32 (MaxPooling2D  (None, 32, 64, 512)  0          ['tf.nn.relu_376[0][0]']
#  )
#
#  tf.nn.relu_379 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_381[0][0]']
#
#  concatenate_83 (Concatenate)   (None, 32, 64, 1024  0           ['max_pooling2d_32[0][0]',
#                                 )                                 'tf.nn.relu_377[0][0]',
#                                                                   'tf.nn.relu_378[0][0]',
#                                                                   'tf.nn.relu_379[0][0]']
#
#  conv2d_388 (Conv2D)            (None, 32, 64, 512)  524800      ['concatenate_83[0][0]']
#
#  batch_normalization_382 (Batch  (None, 32, 64, 512)  2048       ['conv2d_388[0][0]']
#  Normalization)
#
#  tf.nn.relu_380 (TFOpLambda)    (None, 32, 64, 512)  0           ['batch_normalization_382[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_380[0][0]']
#
#  batch_normalization_383 (Batch  (None, 32, 64, 256)  1024       ['conv2d_389[0][0]']
#  Normalization)
#
#  tf.nn.relu_381 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_383[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_381[0][0]']
#
#  batch_normalization_384 (Batch  (None, 32, 64, 128)  512        ['conv2d_390[0][0]']
#  Normalization)
#
#  tf.nn.relu_382 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_384[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_382[0][0]']
#
#  batch_normalization_385 (Batch  (None, 32, 64, 128)  512        ['conv2d_391[0][0]']
#  Normalization)
#
#  tf.nn.relu_383 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_385[0][0]']
#
#  concatenate_84 (Concatenate)   (None, 32, 64, 1024  0           ['tf.nn.relu_380[0][0]',
#                                 )                                 'tf.nn.relu_381[0][0]',
#                                                                   'tf.nn.relu_382[0][0]',
#                                                                   'tf.nn.relu_383[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 32, 64, 512)  524800      ['concatenate_84[0][0]']
#
#  batch_normalization_386 (Batch  (None, 32, 64, 512)  2048       ['conv2d_392[0][0]']
#  Normalization)
#
#  tf.nn.relu_384 (TFOpLambda)    (None, 32, 64, 512)  0           ['batch_normalization_386[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 32, 64, 256)  1179904     ['tf.nn.relu_384[0][0]']
#
#  batch_normalization_387 (Batch  (None, 32, 64, 256)  1024       ['conv2d_393[0][0]']
#  Normalization)
#
#  tf.nn.relu_385 (TFOpLambda)    (None, 32, 64, 256)  0           ['batch_normalization_387[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 32, 64, 128)  295040      ['tf.nn.relu_385[0][0]']
#
#  batch_normalization_388 (Batch  (None, 32, 64, 128)  512        ['conv2d_394[0][0]']
#  Normalization)
#
#  tf.nn.relu_386 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_388[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 32, 64, 128)  147584      ['tf.nn.relu_386[0][0]']
#
#  batch_normalization_389 (Batch  (None, 32, 64, 128)  512        ['conv2d_395[0][0]']
#  Normalization)
#
#  tf.nn.relu_387 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_389[0][0]']
#
#  concatenate_85 (Concatenate)   (None, 32, 64, 1024  0           ['tf.nn.relu_384[0][0]',
#                                 )                                 'tf.nn.relu_385[0][0]',
#                                                                   'tf.nn.relu_386[0][0]',
#                                                                   'tf.nn.relu_387[0][0]']
#
#  tf.nn.avg_pool2d_9 (TFOpLambda  (None, 32, 64, 1024  0          ['concatenate_85[0][0]']
# ...
#  up_sampling2d_9 (UpSampling2D)  (None, 32, 64, 128)  0          ['tf.nn.relu_388[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 32, 64, 128)  147584      ['up_sampling2d_9[0][0]']
#
#  batch_normalization_391 (Batch  (None, 32, 64, 128)  512        ['conv2d_397[0][0]']
#  Normalization)
#
#  conv2d_401 (Conv2D)            (None, 64, 128, 128  65664       ['concatenate_82[0][0]']
#                                 )
#
#  tf.nn.relu_389 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_391[0][0]']
#
#  batch_normalization_395 (Batch  (None, 64, 128, 128  512        ['conv2d_401[0][0]']
#  Normalization)                 )
#
#  tf.nn.avg_pool2d_10 (TFOpLambd  (None, 32, 64, 128)  0          ['tf.nn.relu_389[0][0]']
#  a)
#
#  tf.nn.relu_392 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_395[0][0]']
#                                 )
#
#  conv2d_398 (Conv2D)            (None, 32, 64, 128)  16512       ['tf.nn.avg_pool2d_10[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 64, 128, 128  147584      ['tf.nn.relu_392[0][0]']
#                                 )
#
#  conv2d_399 (Conv2D)            (None, 32, 64, 128)  16512       ['conv2d_398[0][0]']
#
#  batch_normalization_396 (Batch  (None, 64, 128, 128  512        ['conv2d_402[0][0]']
#  Normalization)                 )
#
#  batch_normalization_392 (Batch  (None, 32, 64, 128)  512        ['conv2d_399[0][0]']
#  Normalization)
#
#  tf.nn.relu_393 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_396[0][0]']
#                                 )
#
#  tf.nn.relu_390 (TFOpLambda)    (None, 32, 64, 128)  0           ['batch_normalization_392[0][0]']
#
#  tf.nn.avg_pool2d_11 (TFOpLambd  (None, 64, 128, 128  0          ['tf.nn.relu_393[0][0]']
#  a)                             )
#
#  batch_normalization_393 (Batch  (None, 32, 64, 128)  512        ['tf.nn.relu_390[0][0]']
#  Normalization)
#
#  conv2d_403 (Conv2D)            (None, 64, 128, 128  16512       ['tf.nn.avg_pool2d_11[0][0]']
#                                 )
#
#  tf.math.sigmoid_6 (TFOpLambda)  (None, 32, 64, 128)  0          ['batch_normalization_393[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 64, 128, 128  16512       ['conv2d_403[0][0]']
#                                 )
#
#  multiply_6 (Multiply)          (None, 32, 64, 128)  0           ['tf.math.sigmoid_6[0][0]',
#                                                                   'up_sampling2d_9[0][0]']
#
#  batch_normalization_397 (Batch  (None, 64, 128, 128  512        ['conv2d_404[0][0]']
#  Normalization)                 )
#
#  add_6 (Add)                    (None, 32, 64, 128)  0           ['multiply_6[0][0]',
#                                                                   'up_sampling2d_9[0][0]']
#
#  tf.nn.relu_394 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_397[0][0]']
#                                 )
#
#  up_sampling2d_10 (UpSampling2D  (None, 64, 128, 128  0          ['add_6[0][0]']
#  )                              )
#
#  batch_normalization_398 (Batch  (None, 64, 128, 128  512        ['tf.nn.relu_394[0][0]']
#  Normalization)                 )
#
#  conv2d_400 (Conv2D)            (None, 64, 128, 128  147584      ['up_sampling2d_10[0][0]']
#                                 )
#
#  tf.math.sigmoid_7 (TFOpLambda)  (None, 64, 128, 128  0          ['batch_normalization_398[0][0]']
#                                 )
#
#  batch_normalization_394 (Batch  (None, 64, 128, 128  512        ['conv2d_400[0][0]']
#  Normalization)                 )
#
#  multiply_7 (Multiply)          (None, 64, 128, 128  0           ['tf.math.sigmoid_7[0][0]',
#                                 )                                 'tf.nn.relu_392[0][0]']
#
#  tf.nn.relu_391 (TFOpLambda)    (None, 64, 128, 128  0           ['batch_normalization_394[0][0]']
#                                 )
#
#  add_7 (Add)                    (None, 64, 128, 128  0           ['multiply_7[0][0]',
#                                 )                                 'tf.nn.relu_391[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 128, 256, 12  0          ['add_7[0][0]']
#  )                              8)
#
#  conv2d_405 (Conv2D)            (None, 128, 256, 25  295168      ['up_sampling2d_11[0][0]']
#                                 6)
#
#  batch_normalization_399 (Batch  (None, 128, 256, 25  1024       ['conv2d_405[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_395 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_399[0][0]']
#                                 6)
#
#  concatenate_86 (Concatenate)   (None, 128, 256, 51  0           ['tf.nn.relu_395[0][0]',
#                                 2)                                'concatenate_77[0][0]']
#
#  conv2d_406 (Conv2D)            (None, 128, 256, 25  131328      ['concatenate_86[0][0]']
#                                 6)
#
#  batch_normalization_400 (Batch  (None, 128, 256, 25  1024       ['conv2d_406[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_396 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_400[0][0]']
#                                 6)
#
#  tf.nn.avg_pool2d_12 (TFOpLambd  (None, 128, 256, 25  0          ['tf.nn.relu_396[0][0]']
#  a)                             6)
#
#  conv2d_407 (Conv2D)            (None, 128, 256, 25  65792       ['tf.nn.avg_pool2d_12[0][0]']
#                                 6)
#
#  tf.nn.relu_397 (TFOpLambda)    (None, 128, 256, 25  0           ['conv2d_407[0][0]']
#                                 6)
#
#  conv2d_408 (Conv2D)            (None, 128, 256, 25  65792       ['tf.nn.relu_397[0][0]']
#                                 6)
#
#  tf.math.sigmoid_8 (TFOpLambda)  (None, 128, 256, 25  0          ['conv2d_408[0][0]']
#                                 6)
#
#  multiply_8 (Multiply)          (None, 128, 256, 25  0           ['tf.math.sigmoid_8[0][0]',
#                                 6)                                'tf.nn.relu_396[0][0]']
#
#  add_8 (Add)                    (None, 128, 256, 25  0           ['multiply_8[0][0]',
#                                 6)                                'tf.nn.relu_396[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 128, 256, 25  590080      ['add_8[0][0]']
#                                 6)
#
#  batch_normalization_401 (Batch  (None, 128, 256, 25  1024       ['conv2d_409[0][0]']
#  Normalization)                 6)
#
#  tf.nn.relu_398 (TFOpLambda)    (None, 128, 256, 25  0           ['batch_normalization_401[0][0]']
#                                 6)
#
#  conv2d_410 (Conv2D)            (None, 128, 256, 19  4883        ['tf.nn.relu_398[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 128, 256, 19  0           ['conv2d_410[0][0]']
#                                 )
#
#  up_sampling2d_12 (UpSampling2D  (None, 1024, 2048,   0          ['dropout_2[0][0]']
#  )                              19)
#
#  tf.cast_2 (TFOpLambda)         (None, 1024, 2048,   0           ['up_sampling2d_12[0][0]']
#                                 19)
#
#  tf.nn.softmax_2 (TFOpLambda)   (None, 1024, 2048,   0           ['tf.cast_2[0][0]']
#                                 19)
#
# ==================================================================================================
# Total params: 11,225,555
# Trainable params: 11,208,211
# Non-trainable params: 17,344
# __________________________________________________________________________________________________

# %%
#flops at 1024 x 2048x1536 resolution

from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

from keras_flops import get_flops


# Calculae FLOPS
flops = get_flops(STDC2_seg, batch_size=1)
print(f"FLOPS: {flops / 10 ** 9:.03} G")
# Out:
# FLOPS: 2.97e+03 G
