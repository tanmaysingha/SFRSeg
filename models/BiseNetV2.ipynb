# %%
###BiseNetV2
# The following code is taken from the following public reposiotory. No modification has been made.
#https://github.com/markus-k/bisenetv2-tf2
#paper: chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://arxiv.org/pdf/2004.02147.pdf
#publication link: https://link.springer.com/article/10.1007/s11263-021-01515-2

import tensorflow as tf

import tensorflow.keras.layers as layers
import tensorflow.keras.losses as losses
import tensorflow.keras.metrics as metrics
import tensorflow.keras.models as models
import tensorflow.keras.optimizers as optimizers


# default input shape
INPUT_SHAPE = (512, 1024, 3)


def ge_layer(x_in, c, e=6, stride=1):
    x = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(x_in)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    if stride == 2:
        x = layers.DepthwiseConv2D(depth_multiplier=e, kernel_size=(3,3), strides=2, padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        y = layers.DepthwiseConv2D(depth_multiplier=e, kernel_size=(3,3), strides=2, padding='same')(x_in)
        y = layers.BatchNormalization()(y)
        y = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(y)
        y = layers.BatchNormalization()(y)
    else:
        y = x_in
        
    x = layers.DepthwiseConv2D(depth_multiplier=e, kernel_size=(3,3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Add()([x, y])
    x = layers.Activation('relu')(x)
    return x


def stem(x_in, c):
    x = layers.Conv2D(filters=c, kernel_size=(3,3), strides=2, padding='same')(x_in)
    x = layers.BatchNormalization()(x)
    x_split = layers.Activation('relu')(x)
    
    x = layers.Conv2D(filters=c // 2, kernel_size=(1,1), padding='same')(x_split)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    x = layers.Conv2D(filters=c, kernel_size=(3,3), strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    y = layers.MaxPooling2D()(x_split)
    
    x = layers.Concatenate()([x, y])
    x = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    return x


def detail_conv2d(x_in, c, stride=1):
    x = layers.Conv2D(filters=c, kernel_size=(3,3), strides=stride, padding='same')(x_in)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    return x


def context_embedding(x_in, c):
    x = layers.GlobalAveragePooling2D()(x_in)
    x = layers.BatchNormalization()(x)
    
    x = layers.Reshape((1,1,c))(x)
    
    x = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    # broadcasting no needed
    
    x = layers.Add()([x, x_in])
    x = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(x)
    return x


def bilateral_guided_aggregation(detail, semantic, c):
    # detail branch
    detail_a = layers.DepthwiseConv2D(kernel_size=(3,3), padding='same')(detail)
    detail_a = layers.BatchNormalization()(detail_a)
    
    detail_a = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(detail_a)
    
    detail_b = layers.Conv2D(filters=c, kernel_size=(3,3), strides=2, padding='same')(detail)
    detail_b = layers.BatchNormalization()(detail_b)
    
    detail_b = layers.AveragePooling2D((3,3), strides=2, padding='same')(detail_b)
    
    # semantic branch
    semantic_a = layers.DepthwiseConv2D(kernel_size=(3,3), padding='same')(semantic)
    semantic_a = layers.BatchNormalization()(semantic_a)
    
    semantic_a = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(semantic_a)
    semantic_a = layers.Activation('sigmoid')(semantic_a)
    
    semantic_b = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(semantic)
    semantic_b = layers.BatchNormalization()(semantic_b)
    
    semantic_b = layers.UpSampling2D((4,4), interpolation='bilinear')(semantic_b)
    semantic_b = layers.Activation('sigmoid')(semantic_b)
    
    # combining
    detail = layers.Multiply()([detail_a, semantic_b])
    semantic = layers.Multiply()([semantic_a, detail_b])
    
    # this layer is not mentioned in the paper !?
    #semantic = layers.UpSampling2D((4,4))(semantic)
    semantic = layers.UpSampling2D((4,4), interpolation='bilinear')(semantic)
    
    x = layers.Add()([detail, semantic])
    x = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    return x


def seg_head(x_in, c_t, s, n):
    x = layers.Conv2D(filters=c_t, kernel_size=(3,3), padding='same')(x_in)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    x = layers.Conv2D(filters=n, kernel_size=(3,3), padding='same')(x)
    x = layers.UpSampling2D((s,s), interpolation='bilinear')(x)
    
    return x


class ArgmaxMeanIOU(metrics.MeanIoU):
    def update_state(self, y_true, y_pred, sample_weight=None):
        return super().update_state(tf.argmax(y_true, axis=-1), tf.argmax(y_pred, axis=-1), sample_weight)


def bisenetv2(num_classes=2, out_scale=8, input_shape=INPUT_SHAPE, l=4, seghead_expand_ratio=2):
    x_in = layers.Input(input_shape)

    # semantic branch
    # S1 + S2
    x = stem(x_in, 64 // l)
    
    # S3
    x = ge_layer(x, 128 // l, stride=2)
    x = ge_layer(x, 128 // l, stride=1)

    # S4
    x = ge_layer(x, 64, stride=2)
    x = ge_layer(x, 64, stride=1)

    # S5
    x = ge_layer(x, 128, stride=2)

    x = ge_layer(x, 128, stride=1)
    x = ge_layer(x, 128, stride=1)
    x = ge_layer(x, 128, stride=1)

    x = context_embedding(x, 128)

    # detail branch
    # S1
    y = detail_conv2d(x_in, 64, stride=2)
    y = detail_conv2d(y, 64, stride=1)

    # S2
    y = detail_conv2d(y, 64, stride=2)
    y = detail_conv2d(y, 64, stride=1)
    y = detail_conv2d(y, 64, stride=1)

    # S3
    y = detail_conv2d(y, 128, stride=2)
    y = detail_conv2d(y, 128, stride=1)
    y = detail_conv2d(y, 128, stride=1)

    x = bilateral_guided_aggregation(y, x, 128)

    x = seg_head(x, num_classes * seghead_expand_ratio, out_scale, num_classes)
    
    model = models.Model(inputs=[x_in], outputs=[x])
    
    # set weight initializers
    for layer in model.layers:
        if hasattr(layer, 'kernel_initializer'):
            layer.kernel_initializer = tf.keras.initializers.HeNormal()
        if hasattr(layer, 'depthwise_initializer'):
            layer.depthwise_initializer = tf.keras.initializers.HeNormal()

    return model


def bisenetv2_compiled(num_classes, decay_steps=10e3, momentum=0.9, weight_decay=0.0005, **kwargs):
    model = bisenetv2(num_classes, **kwargs)

    schedule = optimizers.schedules.PolynomialDecay(
        initial_learning_rate=5e-2,
        decay_steps=decay_steps,
        power=0.9
    )

    try:
        import tensorflow_addons as tfa

        sgd = tfa.optimizers.SGDW(
            weight_decay=weight_decay,
            learning_rate=schedule,
            momentum=momentum,
        )
    except ImportError:
        print('tensorflow_addons not available, not using weight-decay')

        sgd = optimizers.SGD(
            learning_rate=schedule,
            momentum=momentum,
        )

    cce = losses.CategoricalCrossentropy(from_logits=True)

    model.compile(sgd, loss=cce,
                  metrics=['accuracy', ArgmaxMeanIOU(num_classes)]) 
    
    return model


def bisenetv2_output_shape(num_classes, scale, input_shape=INPUT_SHAPE):
    return ((input_shape[0] // 8) * scale, 
            (input_shape[1] // 8) * scale, 
            num_classes)

# %%
model = bisenetv2(num_classes=19, out_scale=8, input_shape=(1024,2048,3), l=4, seghead_expand_ratio=3)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1024, 2048,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, 512, 1024, 1  448         ['input_1[0][0]']
#                                 6)
#
#  batch_normalization (BatchNorm  (None, 512, 1024, 1  64         ['conv2d[0][0]']
#  alization)                     6)
#
#  activation (Activation)        (None, 512, 1024, 1  0           ['batch_normalization[0][0]']
#                                 6)
#
#  conv2d_1 (Conv2D)              (None, 512, 1024, 8  136         ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 1024, 8  32         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 1024, 8  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 512, 16  1168        ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 256, 512, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 256, 512, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 512, 16  0           ['activation[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 256, 512, 32  0           ['activation_2[0][0]',
#                                 )                                 'max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 256, 512, 16  4624        ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 256, 512, 16  64         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 256, 512, 16  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 256, 512, 32  4640        ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 256, 512, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 256, 512, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 128, 256, 19  1920       ['activation_4[0][0]']
#  v2D)                           2)
#
#  batch_normalization_5 (BatchNo  (None, 128, 256, 19  768        ['depthwise_conv2d[0][0]']
#  rmalization)                   2)
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 128, 256, 11  11520      ['batch_normalization_5[0][0]']
#  onv2D)                         52)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 128, 256, 96  960        ['activation_3[0][0]']
#  onv2D)                         )
#
#  batch_normalization_8 (BatchNo  (None, 128, 256, 11  4608       ['depthwise_conv2d_2[0][0]']
#  rmalization)                   52)
#
#  batch_normalization_6 (BatchNo  (None, 128, 256, 96  384        ['depthwise_conv2d_1[0][0]']
#  rmalization)                   )
#
#  conv2d_6 (Conv2D)              (None, 128, 256, 32  36896       ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 256, 32  3104        ['batch_normalization_6[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 128, 256, 32  128        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  batch_normalization_7 (BatchNo  (None, 128, 256, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 128, 256, 32  0           ['batch_normalization_9[0][0]',
#                                 )                                 'batch_normalization_7[0][0]']
#
#  activation_5 (Activation)      (None, 128, 256, 32  0           ['add[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 128, 256, 32  9248        ['activation_5[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 128, 256, 32  128        ['conv2d_7[0][0]']
#  ormalization)                  )
#
#  activation_6 (Activation)      (None, 128, 256, 32  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 128, 256, 19  1920       ['activation_6[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_11 (BatchN  (None, 128, 256, 19  768        ['depthwise_conv2d_3[0][0]']
#  ormalization)                  2)
#
#  conv2d_8 (Conv2D)              (None, 128, 256, 32  6176        ['batch_normalization_11[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 128, 256, 32  128        ['conv2d_8[0][0]']
#  ormalization)                  )
#
#  add_1 (Add)                    (None, 128, 256, 32  0           ['batch_normalization_12[0][0]',
#                                 )                                 'activation_5[0][0]']
#
#  activation_7 (Activation)      (None, 128, 256, 32  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 128, 256, 64  18496       ['activation_7[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 128, 256, 64  256        ['conv2d_9[0][0]']
#  ormalization)                  )
#
#  activation_8 (Activation)      (None, 128, 256, 64  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 64, 128, 384  3840       ['activation_8[0][0]']
#  onv2D)                         )
#
#  batch_normalization_14 (BatchN  (None, 64, 128, 384  1536       ['depthwise_conv2d_4[0][0]']
#  ormalization)                  )
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 64, 128, 230  23040      ['batch_normalization_14[0][0]']
#  onv2D)                         4)
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 64, 128, 192  1920       ['activation_7[0][0]']
#  onv2D)                         )
#
#  batch_normalization_17 (BatchN  (None, 64, 128, 230  9216       ['depthwise_conv2d_6[0][0]']
#  ormalization)                  4)
#
#  batch_normalization_15 (BatchN  (None, 64, 128, 192  768        ['depthwise_conv2d_5[0][0]']
#  ormalization)                  )
#
#  conv2d_11 (Conv2D)             (None, 64, 128, 64)  147520      ['batch_normalization_17[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 128, 64)  12352       ['batch_normalization_15[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 128, 64)  256        ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 64, 128, 64)  256        ['conv2d_10[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 64, 128, 64)  0           ['batch_normalization_18[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_9 (Activation)      (None, 64, 128, 64)  0           ['add_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 128, 64)  36928       ['activation_9[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 128, 64)  256        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 128, 64)  0           ['batch_normalization_19[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 64, 128, 384  3840       ['activation_10[0][0]']
#  onv2D)                         )
#
#  batch_normalization_20 (BatchN  (None, 64, 128, 384  1536       ['depthwise_conv2d_7[0][0]']
#  ormalization)                  )
#
#  conv2d_13 (Conv2D)             (None, 64, 128, 64)  24640       ['batch_normalization_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 128, 64)  256        ['conv2d_13[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 64, 128, 64)  0           ['batch_normalization_21[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_11 (Activation)     (None, 64, 128, 64)  0           ['add_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 128, 128  73856       ['activation_11[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 64, 128, 128  512        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 64, 128, 128  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 32, 64, 768)  7680       ['activation_12[0][0]']
#  onv2D)
#
#  batch_normalization_23 (BatchN  (None, 32, 64, 768)  3072       ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  depthwise_conv2d_10 (Depthwise  (None, 32, 64, 4608  46080      ['batch_normalization_23[0][0]']
#  Conv2D)                        )
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 32, 64, 384)  3840       ['activation_11[0][0]']
#  onv2D)
#
#  batch_normalization_26 (BatchN  (None, 32, 64, 4608  18432      ['depthwise_conv2d_10[0][0]']
#  ormalization)                  )
#
#  batch_normalization_24 (BatchN  (None, 32, 64, 384)  1536       ['depthwise_conv2d_9[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 32, 64, 128)  589952      ['batch_normalization_26[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 64, 128)  49280       ['batch_normalization_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 64, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 32, 64, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 64, 128)  0           ['batch_normalization_27[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  activation_13 (Activation)     (None, 32, 64, 128)  0           ['add_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 64, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 64, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 64, 128)  0           ['batch_normalization_28[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 32, 64, 768)  7680       ['activation_14[0][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 32, 64, 768)  3072       ['depthwise_conv2d_11[0][0]']
#  ormalization)
#
#  conv2d_18 (Conv2D)             (None, 32, 64, 128)  98432       ['batch_normalization_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 64, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 64, 128)  0           ['batch_normalization_30[0][0]',
#                                                                   'activation_13[0][0]']
#
#  activation_15 (Activation)     (None, 32, 64, 128)  0           ['add_5[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 64, 128)  147584      ['activation_15[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 64, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 64, 128)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 512, 1024, 6  1792        ['input_1[0][0]']
#                                 4)
#
#  depthwise_conv2d_12 (Depthwise  (None, 32, 64, 768)  7680       ['activation_16[0][0]']
#  Conv2D)
#
#  batch_normalization_39 (BatchN  (None, 512, 1024, 6  256        ['conv2d_25[0][0]']
#  ormalization)                  4)
#
#  batch_normalization_32 (BatchN  (None, 32, 64, 768)  3072       ['depthwise_conv2d_12[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 512, 1024, 6  0           ['batch_normalization_39[0][0]']
#                                 4)
#
#  conv2d_20 (Conv2D)             (None, 32, 64, 128)  98432       ['batch_normalization_32[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 512, 1024, 6  36928       ['activation_21[0][0]']
#                                 4)
#
#  batch_normalization_33 (BatchN  (None, 32, 64, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 512, 1024, 6  256        ['conv2d_26[0][0]']
#  ormalization)                  4)
#
#  add_6 (Add)                    (None, 32, 64, 128)  0           ['batch_normalization_33[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_22 (Activation)     (None, 512, 1024, 6  0           ['batch_normalization_40[0][0]']
#                                 4)
#
#  activation_17 (Activation)     (None, 32, 64, 128)  0           ['add_6[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 256, 512, 64  36928       ['activation_22[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 32, 64, 128)  147584      ['activation_17[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 256, 512, 64  256        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  batch_normalization_34 (BatchN  (None, 32, 64, 128)  512        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 256, 512, 64  0           ['batch_normalization_41[0][0]']
#                                 )
#
#  activation_18 (Activation)     (None, 32, 64, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 256, 512, 64  36928       ['activation_23[0][0]']
#                                 )
#
#  depthwise_conv2d_13 (Depthwise  (None, 32, 64, 768)  7680       ['activation_18[0][0]']
#  Conv2D)
#
#  batch_normalization_42 (BatchN  (None, 256, 512, 64  256        ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  batch_normalization_35 (BatchN  (None, 32, 64, 768)  3072       ['depthwise_conv2d_13[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 256, 512, 64  0           ['batch_normalization_42[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 32, 64, 128)  98432       ['batch_normalization_35[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 256, 512, 64  36928       ['activation_24[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 32, 64, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 256, 512, 64  256        ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  add_7 (Add)                    (None, 32, 64, 128)  0           ['batch_normalization_36[0][0]',
#                                                                   'activation_17[0][0]']
#
#  activation_25 (Activation)     (None, 256, 512, 64  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  activation_19 (Activation)     (None, 32, 64, 128)  0           ['add_7[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 128, 256, 12  73856       ['activation_25[0][0]']
#                                 8)
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['activation_19[0][0]']
#  alAveragePooling2D)
#
#  batch_normalization_44 (BatchN  (None, 128, 256, 12  512        ['conv2d_30[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_37 (BatchN  (None, 128)         512         ['global_average_pooling2d[0][0]'
#  ormalization)                                                   ]
#
#  activation_26 (Activation)     (None, 128, 256, 12  0           ['batch_normalization_44[0][0]']
#                                 8)
#
#  reshape (Reshape)              (None, 1, 1, 128)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 128, 256, 12  147584      ['activation_26[0][0]']
#                                 8)
#
#  conv2d_23 (Conv2D)             (None, 1, 1, 128)    16512       ['reshape[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 128, 256, 12  512        ['conv2d_31[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_38 (BatchN  (None, 1, 1, 128)   512         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 128, 256, 12  0           ['batch_normalization_45[0][0]']
#                                 8)
#
#  activation_20 (Activation)     (None, 1, 1, 128)    0           ['batch_normalization_38[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 128, 256, 12  147584      ['activation_27[0][0]']
#                                 8)
#
#  add_8 (Add)                    (None, 32, 64, 128)  0           ['activation_20[0][0]',
#                                                                   'activation_19[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 128, 256, 12  512        ['conv2d_32[0][0]']
#  ormalization)                  8)
#
#  conv2d_24 (Conv2D)             (None, 32, 64, 128)  147584      ['add_8[0][0]']
#
#  activation_28 (Activation)     (None, 128, 256, 12  0           ['batch_normalization_46[0][0]']
#                                 8)
#
#  depthwise_conv2d_15 (Depthwise  (None, 32, 64, 128)  1280       ['conv2d_24[0][0]']
#  Conv2D)
#
#  conv2d_36 (Conv2D)             (None, 32, 64, 128)  147584      ['conv2d_24[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 32, 64, 128)  512        ['depthwise_conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_34 (Conv2D)             (None, 64, 128, 128  147584      ['activation_28[0][0]']
#                                 )
#
#  depthwise_conv2d_14 (Depthwise  (None, 128, 256, 12  1280       ['activation_28[0][0]']
#  Conv2D)                        8)
#
#  batch_normalization_50 (BatchN  (None, 32, 64, 128)  512        ['conv2d_36[0][0]']
#  ormalization)
#
#  conv2d_35 (Conv2D)             (None, 32, 64, 128)  16512       ['batch_normalization_49[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 64, 128, 128  512        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  batch_normalization_47 (BatchN  (None, 128, 256, 12  512        ['depthwise_conv2d_14[0][0]']
#  ormalization)                  8)
#
#  up_sampling2d (UpSampling2D)   (None, 128, 256, 12  0           ['batch_normalization_50[0][0]']
#                                 8)
#
#  activation_29 (Activation)     (None, 32, 64, 128)  0           ['conv2d_35[0][0]']
#
#  average_pooling2d (AveragePool  (None, 32, 64, 128)  0          ['batch_normalization_48[0][0]']
#  ing2D)
#
#  conv2d_33 (Conv2D)             (None, 128, 256, 12  16512       ['batch_normalization_47[0][0]']
#                                 8)
#
#  activation_30 (Activation)     (None, 128, 256, 12  0           ['up_sampling2d[0][0]']
#                                 8)
#
#  multiply_1 (Multiply)          (None, 32, 64, 128)  0           ['activation_29[0][0]',
#                                                                   'average_pooling2d[0][0]']
#
#  multiply (Multiply)            (None, 128, 256, 12  0           ['conv2d_33[0][0]',
#                                 8)                                'activation_30[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 256, 12  0          ['multiply_1[0][0]']
#                                 8)
#
#  add_9 (Add)                    (None, 128, 256, 12  0           ['multiply[0][0]',
#                                 8)                                'up_sampling2d_1[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 128, 256, 12  147584      ['add_9[0][0]']
#                                 8)
#
#  batch_normalization_51 (BatchN  (None, 128, 256, 12  512        ['conv2d_37[0][0]']
#  ormalization)                  8)
#
#  conv2d_38 (Conv2D)             (None, 128, 256, 57  65721       ['batch_normalization_51[0][0]']
#                                 )
#
#  batch_normalization_52 (BatchN  (None, 128, 256, 57  228        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  activation_31 (Activation)     (None, 128, 256, 57  0           ['batch_normalization_52[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 128, 256, 19  9766        ['activation_31[0][0]']
#                                 )
#
#  up_sampling2d_2 (UpSampling2D)  (None, 1024, 2048,   0          ['conv2d_39[0][0]']
#                                 19)
#
# ==================================================================================================
# Total params: 3,188,779
# Trainable params: 3,156,169
# Non-trainable params: 32,610
# __________________________________________________________________________________________________

# %%
#install keras-floops to get the flop counts of the model

# !pip install keras-flops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-flops
#   Downloading keras_flops-0.1.2-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: tensorflow<3.0,>=2.2 in /usr/local/lib/python3.7/dist-packages (from keras-flops) (2.9.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.27.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.21.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.17.3)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.12)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (4.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.0.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.9.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (57.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (14.0.6)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (21.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.49.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<3.0,>=2.2->keras-flops) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<3.0,>=2.2->keras-flops) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (3.9.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3.0,>=2.2->keras-flops) (3.2.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow<3.0,>=2.2->keras-flops) (3.0.9)
# Installing collected packages: keras-flops
# Successfully installed keras-flops-0.1.2

# %%
#flops at 1024 x 2048x1536 resolution

#In litera

from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

from keras_flops import get_flops


# Calculae FLOPS for STDC1 classification model
flops = get_flops(model, batch_size=1)
print(f"FLOPS: {flops / 10 ** 9:.03} G")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/nn_ops.py:5219: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# FLOPS: 1.34e+02 G
