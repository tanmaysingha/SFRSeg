W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.088505: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.111856: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.135061: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.158356: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.181517: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.204685: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.231528: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.254711: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.278814: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.301202: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.323989: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.347621: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.371284: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.394606: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.418191: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.441985: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.465235: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.490461: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.513825: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.537362: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.560767: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.584683: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.608154: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.632581: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.655715: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.679344: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.702993: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.726314: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.749705: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.773187: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.796643: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.820036: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.843305: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.866957: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.890395: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.913941: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.937528: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.960960: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:01.984261: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.011567: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.035098: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.058458: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.081689: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.105309: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.136395: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.159629: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.183795: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.207088: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.231932: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.253980: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.277188: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.300525: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.323732: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.346905: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.370010: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.393164: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.415905: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.442148: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.467472: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.491894: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.515461: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.538654: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.561695: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.584637: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.608139: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.633926: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.656539: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.680015: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.703173: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.726427: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.749702: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.773020: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.796642: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.820430: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.843715: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.867003: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.890513: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.913591: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.937089: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.959575: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:02.983486: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:03.006781: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# 2022-10-29 12:02:03.029772: W tensorflow/compiler/tf2tensorrt/kernels/trt_engine_op.cc:629] TF-TRT Warning: Engine retrieval for input shapes: [[4,384,1280,128]] failed. Running native segment for PartitionedCall/TRTEngineOp_0_1
# batched_input shape:  (4, 384, 1280, 3)
# Throughput: 170 images/s

# %%
### The following code meaure the Throughout (Frame Per Second (FPS))
### of ICNet tensorRT FP 16 model at 640 x 896 input resolution (CamVid dataset).

from tensorflow import keras
import tensorflow as tf
import numpy as np
import time
from tensorflow.python.saved_model import tag_constants
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import os

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

batch_size = 4
h =640
w =896
batched_input = np.zeros((batch_size, h, w, 3), dtype=np.float32)

for i in range(batch_size):
  ### path of the image directory  
  img_path = '/home/jovyan/work/Keras_tensorRT_models/data/img%d.png' % (i % 4)
  img = image.load_img(img_path, target_size=(h, w))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  #x = preprocess_input(x)
  batched_input[i, :] = x
batched_input = tf.constant(batched_input)
print('batched_input shape: ', batched_input.shape)

def benchmark_tftrt(input_saved_model):
    saved_model_loaded = tf.saved_model.load(input_saved_model, tags=[tag_constants.SERVING])
    infer = saved_model_loaded.signatures['serving_default']

    N_warmup_run = 20
    N_run = 200
    elapsed_time = []

    for i in range(N_warmup_run):
      labeling = infer(batched_input)

    for i in range(N_run):
      start_time = time.time()
      labeling = infer(batched_input)
      #prob = labeling['probs'].numpy()
      end_time = time.time()
      elapsed_time = np.append(elapsed_time, end_time - start_time)
      #if i % 20 == 0:
        #print('Step {}: {:4.1f}ms'.format(i, (elapsed_time[-50:].mean()) * 1000))

    print('Throughput: {:.0f} images/s'.format(N_run * batch_size / elapsed_time.sum()))

### load the TRT FP16 model    
FPS16 = benchmark_tftrt('ICNet_camvid_TFTRT_FP16')
# Out:
# 2022-10-29 13:36:13.620190: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-29 13:36:14.971514: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-10-29 13:36:15.027568: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:1b:00.0 name: NVIDIA TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-10-29 13:36:15.027621: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-29 13:36:15.029565: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-10-29 13:36:15.031698: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-10-29 13:36:15.032034: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-10-29 13:36:15.036991: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-10-29 13:36:15.038457: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-10-29 13:36:15.043948: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-10-29 13:36:15.053725: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-10-29 13:36:15.054281: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-29 13:36:15.066653: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2022-10-29 13:36:15.070519: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56482f206c80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-10-29 13:36:15.070577: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-10-29 13:36:15.428370: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56483058a760 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-10-29 13:36:15.428421: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA TITAN RTX, Compute Capability 7.5
# 2022-10-29 13:36:15.432083: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:1b:00.0 name: NVIDIA TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-10-29 13:36:15.432133: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-29 13:36:15.432165: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-10-29 13:36:15.432181: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-10-29 13:36:15.432198: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-10-29 13:36:15.432214: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-10-29 13:36:15.432229: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-10-29 13:36:15.432245: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-10-29 13:36:15.439812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-10-29 13:36:15.439964: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-29 13:36:16.359741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-29 13:36:16.359818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2022-10-29 13:36:16.359831: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2022-10-29 13:36:16.363824: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-10-29 13:36:16.363880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22476 MB memory) -> physical GPU (device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:1b:00.0, compute capability: 7.